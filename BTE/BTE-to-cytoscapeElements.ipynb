# %% [markdown]
# #### Import BTE modules

# %%
import pandas as pandas
from biothings_explorer.query.predict import Predict
from biothings_explorer.query.visualize import display_graph
from biothings_explorer.user_query_dispatcher import FindConnection
from biothings_explorer.hint import Hint
import nest_asyncio
nest_asyncio.apply()
import networkx as nx
import matplotlib.pyplot as plt

# %matplotlib inline
import warnings
warnings.filterwarnings("ignore") 

ht = Hint()

# %% [markdown]
# ### Find representation of VAMP2 in BTE

# %%
# find representations of VAMP2 (ENSG00000220205)
vamp2 = ht.query("ENSG00000220205") ["Gene"] [0]
vamp2
# Out:
# {'NCBIGene': '6844',
#  'name': 'vesicle associated membrane protein 2',
#  'SYMBOL': 'VAMP2',
#  'UMLS': 'C1421419',
#  'HGNC': '12643',
#  'UNIPROTKB': 'P63027',
#  'ENSEMBL': 'ENSG00000220205',
#  'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6844'},
#  'display': 'NCBIGene(6844) ENSEMBL(ENSG00000220205) HGNC(12643) UMLS(C1421419) UNIPROTKB(P63027) SYMBOL(VAMP2)',
#  'type': 'Gene'}

# %% [markdown]
# ### Biological Process related to VAMP2
# Find all the **Biological Process** directly connected to the gene: **VAMP2** (no intermediate nodes [ ])

# %%
fc_BP = FindConnection(input_obj=vamp2, output_obj="BiologicalProcess", intermediate_nodes= [])

# %%
fc_BP.connect(verbose=True)
# Out:
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'VAMP2' and 'BiologicalProcess'. Paths will have 0 intermediate node.
#
#
#
# ========== QUERY #1 -- fetch all BiologicalProcess entities linked to VAMP2 ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because VAMP2 is of type 'Gene', BTE will query our meta-KG for APIs that can take 'Gene' as input and 'BiologicalProcess' as output
#
# BTE found 3 apis:
#
# API 1. cord_gene(1 API call)
# API 2. mygene(1 API call)
# API 3. semmed_gene(11 API calls)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 3.6: https://biothings.ncats.io/semmedgene/query?fields=positively_regulates (POST -d q=C1421419&scopes=umls)
# API 3.1: https://biothings.ncats.io/semmedgene/query?fields=related_to (POST -d q=C1421419&scopes=umls)
# API 3.7: https://biothings.ncats.io/semmedgene/query?fields=negatively_regulates (POST -d q=C1421419&scopes=umls)
# API 3.2: https://biothings.ncats.io/semmedgene/query?fields=negatively_regulated_by (POST -d q=C1421419&scopes=umls)
# API 2.1: https://mygene.info/v3/query?fields=go.BP (POST -d q=6844&scopes=entrezgene)
# API 3.11: https://biothings.ncats.io/semmedgene/query?fields=affected_by (POST -d q=C1421419&scopes=umls)
# API 3.9: https://biothings.ncats.io/semmedgene/query?fields=causes (POST -d q=C1421419&scopes=umls)
# API 1.1: https://biothings.ncats.io/cord_gene/query?fields=associated_with (POST -d q=12643&scopes=hgnc)
# API 3.8: https://biothings.ncats.io/semmedgene/query?fields=disrupts (POST -d q=C1421419&scopes=umls)
# API 3.10: https://biothings.ncats.io/semmedgene/query?fields=positively_regulated_by (POST -d q=C1421419&scopes=umls)
# API 3.5: https://biothings.ncats.io/semmedgene/query?fields=affects (POST -d q=C1421419&scopes=umls)
# API 3.4: https://biothings.ncats.io/semmedgene/query?fields=physically_interacts_with (POST -d q=C1421419&scopes=umls)
# API 3.3: https://biothings.ncats.io/semmedgene/query?fields=disrupted_by (POST -d q=C1421419&scopes=umls)
#
#
# ==== Step #3: Output normalization ====
#
# API 3.1 semmed_gene: No hits
# API 1.1 cord_gene: 4 hits
# API 3.2 semmed_gene: No hits
# API 2.1 mygene: 29 hits
# API 3.3 semmed_gene: No hits
# API 3.4 semmed_gene: No hits
# API 3.5 semmed_gene: 6 hits
# API 3.6 semmed_gene: No hits
# API 3.7 semmed_gene: No hits
# API 3.8 semmed_gene: 1 hits
# API 3.9 semmed_gene: 1 hits
# API 3.10 semmed_gene: No hits
# API 3.11 semmed_gene: No hits
#
# After id-to-object translation, BTE retrieved 39 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# In the #1 query, BTE found 39 unique BiologicalProcess nodes

# %%
#Display results in a table 
df_BP=fc_BP.display_table_view ()
df_BP
# Out:
#     input input_type                   pred1                     pred1_source  \
# 0   VAMP2       Gene                 affects                           SEMMED
# 1   VAMP2       Gene                 affects                           SEMMED
# 2   VAMP2       Gene                 affects                           SEMMED
# 3   VAMP2       Gene                 affects                           SEMMED
# 4   VAMP2       Gene                 affects                           SEMMED
# 5   VAMP2       Gene                 affects                           SEMMED
# 6   VAMP2       Gene                disrupts                           SEMMED
# 7   VAMP2       Gene                  causes                           SEMMED
# 8   VAMP2       Gene              related_to  Translator Text Mining Provider
# 9   VAMP2       Gene              related_to  Translator Text Mining Provider
# 10  VAMP2       Gene              related_to  Translator Text Mining Provider
# 11  VAMP2       Gene              related_to  Translator Text Mining Provider
# 12  VAMP2       Gene  functional_association                           entrez
# 13  VAMP2       Gene  functional_association                           entrez
# 14  VAMP2       Gene  functional_association                           entrez
# 15  VAMP2       Gene  functional_association                           entrez
# 16  VAMP2       Gene  functional_association                           entrez
# 17  VAMP2       Gene  functional_association                           entrez
# 18  VAMP2       Gene  functional_association                           entrez
# 19  VAMP2       Gene  functional_association                           entrez
# 20  VAMP2       Gene  functional_association                           entrez
# 21  VAMP2       Gene  functional_association                           entrez
# 22  VAMP2       Gene  functional_association                           entrez
# 23  VAMP2       Gene  functional_association                           entrez
# 24  VAMP2       Gene  functional_association                           entrez
# 25  VAMP2       Gene  functional_association                           entrez
# 26  VAMP2       Gene  functional_association                           entrez
# 27  VAMP2       Gene  functional_association                           entrez
# 28  VAMP2       Gene  functional_association                           entrez
# 29  VAMP2       Gene  functional_association                           entrez
# 30  VAMP2       Gene  functional_association                           entrez
# 31  VAMP2       Gene  functional_association                           entrez
# 32  VAMP2       Gene  functional_association                           entrez
# 33  VAMP2       Gene  functional_association                           entrez
# 34  VAMP2       Gene  functional_association                           entrez
# 35  VAMP2       Gene  functional_association                           entrez
# 36  VAMP2       Gene  functional_association                           entrez
# 37  VAMP2       Gene  functional_association                           entrez
# 38  VAMP2       Gene  functional_association                           entrez
# 39  VAMP2       Gene  functional_association                           entrez
# 40  VAMP2       Gene  functional_association                           entrez
#
#           pred1_api                         pred1_pubmed        output_type  \
# 0   SEMMED Gene API  24356748,20609425,23641074,25762204  BiologicalProcess
# 1   SEMMED Gene API                    28588281,19116655  BiologicalProcess
# 2   SEMMED Gene API                             28264432  BiologicalProcess
# 3   SEMMED Gene API                    15774481,22406549  BiologicalProcess
# 4   SEMMED Gene API                              9341137  BiologicalProcess
# 5   SEMMED Gene API                             17215881  BiologicalProcess
# 6   SEMMED Gene API                             12597859  BiologicalProcess
# 7   SEMMED Gene API                             27527271  BiologicalProcess
# 8     CORD Gene API                                 None  BiologicalProcess
# 9     CORD Gene API                                 None  BiologicalProcess
# 10    CORD Gene API                                 None  BiologicalProcess
# 11    CORD Gene API                                 None  BiologicalProcess
# 12  MyGene.info API                             10099709  BiologicalProcess
# 13  MyGene.info API                                 None  BiologicalProcess
# 14  MyGene.info API                             21873635  BiologicalProcess
# 15  MyGene.info API                             30929742  BiologicalProcess
# 16  MyGene.info API                                 None  BiologicalProcess
# 17  MyGene.info API                                 None  BiologicalProcess
# 18  MyGene.info API                                 None  BiologicalProcess
# 19  MyGene.info API                                 None  BiologicalProcess
# 20  MyGene.info API                                 None  BiologicalProcess
# 21  MyGene.info API                             15217342  BiologicalProcess
# 22  MyGene.info API                                 None  BiologicalProcess
# 23  MyGene.info API                                 None  BiologicalProcess
# 24  MyGene.info API                                 None  BiologicalProcess
# 25  MyGene.info API                                 None  BiologicalProcess
# 26  MyGene.info API                             21873635  BiologicalProcess
# 27  MyGene.info API                                 None  BiologicalProcess
# 28  MyGene.info API                             16677249  BiologicalProcess
# 29  MyGene.info API                             16677249  BiologicalProcess
# 30  MyGene.info API                             18042464  BiologicalProcess
# 31  MyGene.info API                                 None  BiologicalProcess
# 32  MyGene.info API                                 None  BiologicalProcess
# 33  MyGene.info API                                 None  BiologicalProcess
# 34  MyGene.info API                                 None  BiologicalProcess
# 35  MyGene.info API                                 None  BiologicalProcess
# 36  MyGene.info API                                 None  BiologicalProcess
# 37  MyGene.info API                             22144578  BiologicalProcess
# 38  MyGene.info API                                 None  BiologicalProcess
# 39  MyGene.info API                                 None  BiologicalProcess
# 40  MyGene.info API                             18253931  BiologicalProcess
#
#                                           output_name      output_id
# 0                                            C0015283  UMLS:C0015283
# 1                                            C0025246  UMLS:C0025246
# 2                                            C0597304  UMLS:C0597304
# 3                                            C1326474  UMLS:C1326474
# 4                                            C1326489  UMLS:C1326489
# 5                                            C1522290  UMLS:C1522290
# 6                                            C0014139  UMLS:C0014139
# 7                                            C1330957  UMLS:C1330957
# 8                                            LEARNING  GO:GO:0007612
# 9                                                 AER  GO:GO:0070914
# 10                                  INSULIN SECRETION  GO:GO:0030073
# 11                              REVERSE TRANSCRIPTION  GO:GO:0001171
# 12                                         EXOCYTOSIS  GO:GO:0006887
# 13                               POST-GOLGI TRANSPORT  GO:GO:0006892
# 14                                     VESICLE FUSION  GO:GO:0006906
# 15                                     VESICLE FUSION  GO:GO:0006906
# 16                           NEUROTRANSMITTER RELEASE  GO:GO:0007269
# 17                                RESPONSE TO GLUCOSE  GO:GO:0009749
# 18                                GLUTAMATE SECRETION  GO:GO:0014047
# 19                                  PROTEIN TRANSPORT  GO:GO:0015031
# 20                        SYNAPTIC VESICLE EXOCYTOSIS  GO:GO:0016079
# 21                        SYNAPTIC VESICLE EXOCYTOSIS  GO:GO:0016079
# 22            PROTEIN SORTING ALONG SECRETORY PATHWAY  GO:GO:0016192
# 23                   CALCIUM ION-DEPENDENT EXOCYTOSIS  GO:GO:0017156
# 24                           REGULATION OF EXOCYTOSIS  GO:GO:0017157
# 25              CELLULAR RESPONSE TO INSULIN STIMULUS  GO:GO:0032869
# 26                             SNARE COMPLEX ASSEMBLY  GO:GO:0035493
# 27         GOLGI TO PLASMA MEMBRANE PROTEIN TRANSPORT  GO:GO:0043001
# 28                           EOSINOPHIL DEGRANULATION  GO:GO:0043308
# 29                           HETEROPHIL DEGRANULATION  GO:GO:0043312
# 30                  NATURAL KILLER CELL DEGRANULATION  GO:GO:0043320
# 31                       SYNAPTIC VESICLE ENDOCYTOSIS  GO:GO:0048488
# 32                             LONG-TERM POTENTIATION  GO:GO:0060291
# 33           REGULATION OF VESICLE-MEDIATED TRANSPORT  GO:GO:0060627
# 34                     CELLULAR MEMBRANE ORGANISATION  GO:GO:0061024
# 35                           CELLULAR MEMBRANE FUSION  GO:GO:0061025
# 36                                 CHAPERONE ACTIVITY  GO:GO:0065003
# 37                                   MUCUS PRODUCTION  GO:GO:0070254
# 38  POSITIVE REGULATION OF INTRACELLULAR PROTEIN T...  GO:GO:0090316
# 39  REGULATION OF DELAYED RECTIFIER POTASSIUM CHAN...  GO:GO:1902259
# 40     REGULATION OF HISTAMINE SECRETION BY MAST CELL  GO:GO:1903593

# %%
#Display just the Biological Process retrieved
df_BP.output_name.value_counts()
# Out:
# SYNAPTIC VESICLE EXOCYTOSIS                                   2
# VESICLE FUSION                                                2
# GOLGI TO PLASMA MEMBRANE PROTEIN TRANSPORT                    1
# CALCIUM ION-DEPENDENT EXOCYTOSIS                              1
# REGULATION OF VESICLE-MEDIATED TRANSPORT                      1
# POST-GOLGI TRANSPORT                                          1
# C1326489                                                      1
# CHAPERONE ACTIVITY                                            1
# REGULATION OF EXOCYTOSIS                                      1
# MUCUS PRODUCTION                                              1
# GLUTAMATE SECRETION                                           1
# LONG-TERM POTENTIATION                                        1
# POSITIVE REGULATION OF INTRACELLULAR PROTEIN TRANSPORT        1
# PROTEIN SORTING ALONG SECRETORY PATHWAY                       1
# REGULATION OF DELAYED RECTIFIER POTASSIUM CHANNEL ACTIVITY    1
# EOSINOPHIL DEGRANULATION                                      1
# C0015283                                                      1
# RESPONSE TO GLUCOSE                                           1
# CELLULAR RESPONSE TO INSULIN STIMULUS                         1
# AER                                                           1
# C1326474                                                      1
# C0597304                                                      1
# INSULIN SECRETION                                             1
# C1522290                                                      1
# HETEROPHIL DEGRANULATION                                      1
# C0014139                                                      1
# SNARE COMPLEX ASSEMBLY                                        1
# NATURAL KILLER CELL DEGRANULATION                             1
# REVERSE TRANSCRIPTION                                         1
# C1330957                                                      1
# CELLULAR MEMBRANE FUSION                                      1
# SYNAPTIC VESICLE ENDOCYTOSIS                                  1
# PROTEIN TRANSPORT                                             1
# LEARNING                                                      1
# NEUROTRANSMITTER RELEASE                                      1
# REGULATION OF HISTAMINE SECRETION BY MAST CELL                1
# CELLULAR MEMBRANE ORGANISATION                                1
# C0025246                                                      1
# EXOCYTOSIS                                                    1
# Name: output_name, dtype: int64

# %%
# Display id's of the Biological Process retrieved 
bp_output_id = df_BP.output_id.value_counts()
bp_output_id
# Out:
# GO:GO:0006906    2
# GO:GO:0016079    2
# GO:GO:0048488    1
# GO:GO:0016192    1
# UMLS:C1326489    1
# GO:GO:0007269    1
# GO:GO:0032869    1
# GO:GO:0001171    1
# UMLS:C1326474    1
# GO:GO:0006892    1
# UMLS:C0597304    1
# GO:GO:0009749    1
# GO:GO:0006887    1
# GO:GO:0043308    1
# GO:GO:0030073    1
# GO:GO:0070254    1
# GO:GO:0061024    1
# GO:GO:0007612    1
# GO:GO:0043312    1
# GO:GO:0043001    1
# GO:GO:1903593    1
# GO:GO:1902259    1
# GO:GO:0017157    1
# GO:GO:0065003    1
# GO:GO:0060627    1
# GO:GO:0061025    1
# UMLS:C0015283    1
# GO:GO:0035493    1
# GO:GO:0060291    1
# GO:GO:0017156    1
# GO:GO:0015031    1
# GO:GO:0014047    1
# GO:GO:0070914    1
# UMLS:C1522290    1
# UMLS:C1330957    1
# GO:GO:0090316    1
# GO:GO:0043320    1
# UMLS:C0014139    1
# UMLS:C0025246    1
# Name: output_id, dtype: int64

# %% [markdown]
# ###  Query Path: BP>Genes>ChemicalSubstances>Disease
# We want to find all the **Genes** associated to each **BiologicalProcess** connected to VAMP2 (previously retrieved). We also want to find the the **ChemicalSubstances** connecting each gene to **Diseases** of interest (Epilepsy, autism, intelectual disabilities)
#
# For loop:
# 1. Genes connected to the Biological Process (**bp_output_id**)
#     - Representation of Biological Process
#     - Find Genes directly connected to Biological Process. No intermediate nodes.
#     - Filter. Select only the Biological Process that have less than "x" genes related (**threshold_gene**)
#
# 2. Find intermediate ChemicalSubstance connecting Genes and diseases of interest (**diseases_id**)
#     - Representation of genes selected
#     - Representation of Diseases (diseases_id)

# %%
def bp_to_cs (bp_output_id,
              threshold_gene, 
              diseases_id):
    
#Clean ID results
    ##Remove first "GO" character
    BP_ID =[]
    for i in (bp_output_id.index.tolist()): #Get the index of pandas.Series to a list 
        if "GO" in i: 
            BP_ID.append(i[3:]) #Remove the first GO character in the ID and append to sliced list
        else: 
            not_GO_ID = (i) #Remove the not-GO IDs

#Genes connected to the Biological Process
    #Connection BP-Gene
    table_BP_genes_results = []
    for gene in BP_ID: 
        fc = FindConnection(input_obj=(ht.query(gene)["BiologicalProcess"][0]), #Find representation of BP
                            output_obj= "Gene", 
                            intermediate_nodes= [])
        fc.connect(verbose=True)
        fc.results=(fc.display_table_view ())
        
        #Filter BP based on threshold_gene argument
        if len(fc.results) <= threshold_gene: 
            table_BP_genes_results.append(fc.results)
        else: 
            None 

#Concatenate tables BP-Genes      
    df = pandas.concat(table_BP_genes_results)
    #print (df)

    
#Get the Chemical substances related to the genes retrieved
#Connection Gene-Cs-Disease
    final_table = []
    for bp,pred_type,source,gene_id in zip(df["input"], df ["pred1"], df["pred1_pubmed"], df["output_name"]):
        for disease in diseases_id:
            cs = FindConnection(input_obj=(ht.query(gene_id)['Gene'][0]), 
                                output_obj= (ht.query(disease)['Disease'][0]),
                                intermediate_nodes= "ChemicalSubstance") #Next step would be to Filter Chemical Substances (??)
            cs.connect(verbose=True)
            table_results_cs= (cs.display_table_view ())
            #Add columns related to the Biological Process 
            table_results_cs.insert(0, 'BiologicalProcess', bp) #Add biological Process
            table_results_cs.insert(1, 'pred_BP_Gene', pred_type) #Add the association type 
            table_results_cs.insert(2, 'pred_source', source) #Add the source of prediction
            
            final_table.append(table_results_cs)
    
    
#Concatenate tables  Gene-Disease-CS      
    final_results = pandas.concat(final_table)
    return (final_results)

# %% [markdown]
# #### Run for loop

# %%
#List of disease
    #MONDO:0005027: Epilepsy #MONDO:0005260: Autism #MONDO:0001071: intellectual disability

diseases_id= ["MONDO:0005027","MONDO:0005260", "MONDO:0001071"]

#bp_to_cs function
    #Select the Biological Process that have 10 or less genes associated

test = bp_to_cs(bp_output_id, threshold_gene = 10, diseases_id=diseases_id )
# Out:
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'vesicle fusion' and 'Gene'. Paths will have 0 intermediate node.
#
#
#
# ========== QUERY #1 -- fetch all Gene entities linked to vesicle fusion ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because vesicle fusion is of type 'BiologicalProcess', BTE will query our meta-KG for APIs that can take 'BiologicalProcess' as input and 'Gene' as output
#
# BTE found 1 apis:
#
# API 1. cord_biological_process(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.1: https://biothings.ncats.io/cord_bp/query?fields=associated_with (POST -d q=GO:0006906&scopes=go)
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 cord_biological_process: 16 hits
#
# After id-to-object translation, BTE retrieved 16 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# In the #1 query, BTE found 16 unique Gene nodes
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'synaptic vesicle exocytosis' and 'Gene'. Paths will have 0 intermediate node.
#
#
#
# ========== QUERY #1 -- fetch all Gene entities linked to synaptic vesicle exocytosis ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because synaptic vesicle exocytosis is of type 'BiologicalProcess', BTE will query our meta-KG for APIs that can take 'BiologicalProcess' as input and 'Gene' as output
#
# BTE found 1 apis:
#
# API 1. cord_biological_process(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.1: https://biothings.ncats.io/cord_bp/query?fields=associated_with (POST -d q=GO:0016079&scopes=go)
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 cord_biological_process: 4 hits
#
# After id-to-object translation, BTE retrieved 4 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# In the #1 query, BTE found 4 unique Gene nodes
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'synaptic vesicle endocytosis' and 'Gene'. Paths will have 0 intermediate node.
#
#
#
# ========== QUERY #1 -- fetch all Gene entities linked to synaptic vesicle endocytosis ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because synaptic vesicle endocytosis is of type 'BiologicalProcess', BTE will query our meta-KG for APIs that can take 'BiologicalProcess' as input and 'Gene' as output
#
# BTE found 1 apis:
#
# API 1. cord_biological_process(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.1: https://biothings.ncats.io/cord_bp/query?fields=associated_with (POST -d q=GO:0048488&scopes=go)
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 cord_biological_process: No hits
#
# After id-to-object translation, BTE retrieved 0 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'vesicle-mediated transport' and 'Gene'. Paths will have 0 intermediate node.
#
#
#
# ========== QUERY #1 -- fetch all Gene entities linked to vesicle-mediated transport ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because vesicle-mediated transport is of type 'BiologicalProcess', BTE will query our meta-KG for APIs that can take 'BiologicalProcess' as input and 'Gene' as output
#
# BTE found 1 apis:
#
# API 1. cord_biological_process(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.1: https://biothings.ncats.io/cord_bp/query?fields=associated_with (POST -d q=GO:0016192&scopes=go)
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 cord_biological_process: 45 hits
#
# After id-to-object translation, BTE retrieved 45 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# In the #1 query, BTE found 45 unique Gene nodes
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'neurotransmitter secretion' and 'Gene'. Paths will have 0 intermediate node.
#
#
#
# ========== QUERY #1 -- fetch all Gene entities linked to neurotransmitter secretion ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because neurotransmitter secretion is of type 'BiologicalProcess', BTE will query our meta-KG for APIs that can take 'BiologicalProcess' as input and 'Gene' as output
#
# BTE found 1 apis:
#
# API 1. cord_biological_process(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.1: https://biothings.ncats.io/cord_bp/query?fields=associated_with (POST -d q=GO:0007269&scopes=go)
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 cord_biological_process: 18 hits
#
# After id-to-object translation, BTE retrieved 18 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# In the #1 query, BTE found 18 unique Gene nodes
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'cellular response to insulin stimulus' and 'Gene'. Paths will have 0 intermediate node.
#
#
#
# ========== QUERY #1 -- fetch all Gene entities linked to cellular response to insulin stimulus ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because cellular response to insulin stimulus is of type 'BiologicalProcess', BTE will query our meta-KG for APIs that can take 'BiologicalProcess' as input and 'Gene' as output
#
# BTE found 1 apis:
#
# API 1. cord_biological_process(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.1: https://biothings.ncats.io/cord_bp/query?fields=associated_with (POST -d q=GO:0032869&scopes=go)
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 cord_biological_process: No hits
#
# After id-to-object translation, BTE retrieved 0 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'reverse transcription' and 'Gene'. Paths will have 0 intermediate node.
#
#
#
# ========== QUERY #1 -- fetch all Gene entities linked to reverse transcription ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because reverse transcription is of type 'BiologicalProcess', BTE will query our meta-KG for APIs that can take 'BiologicalProcess' as input and 'Gene' as output
#
# BTE found 1 apis:
#
# API 1. cord_biological_process(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.1: https://biothings.ncats.io/cord_bp/query?fields=associated_with (POST -d q=GO:0001171&scopes=go)
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 cord_biological_process: 328 hits
#
# After id-to-object translation, BTE retrieved 328 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# In the #1 query, BTE found 328 unique Gene nodes
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'post-Golgi vesicle-mediated transport' and 'Gene'. Paths will have 0 intermediate node.
#
#
#
# ========== QUERY #1 -- fetch all Gene entities linked to post-Golgi vesicle-mediated transport ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because post-Golgi vesicle-mediated transport is of type 'BiologicalProcess', BTE will query our meta-KG for APIs that can take 'BiologicalProcess' as input and 'Gene' as output
#
# BTE found 1 apis:
#
# API 1. cord_biological_process(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.1: https://biothings.ncats.io/cord_bp/query?fields=associated_with (POST -d q=GO:0006892&scopes=go)
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 cord_biological_process: No hits
#
# After id-to-object translation, BTE retrieved 0 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'response to glucose' and 'Gene'. Paths will have 0 intermediate node.
#
#
#
# ========== QUERY #1 -- fetch all Gene entities linked to response to glucose ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because response to glucose is of type 'BiologicalProcess', BTE will query our meta-KG for APIs that can take 'BiologicalProcess' as input and 'Gene' as output
#
# BTE found 1 apis:
#
# API 1. cord_biological_process(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.1: https://biothings.ncats.io/cord_bp/query?fields=associated_with (POST -d q=GO:0009749&scopes=go)
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 cord_biological_process: 20 hits
#
# After id-to-object translation, BTE retrieved 20 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# In the #1 query, BTE found 20 unique Gene nodes
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'exocytosis' and 'Gene'. Paths will have 0 intermediate node.
#
#
#
# ========== QUERY #1 -- fetch all Gene entities linked to exocytosis ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because exocytosis is of type 'BiologicalProcess', BTE will query our meta-KG for APIs that can take 'BiologicalProcess' as input and 'Gene' as output
#
# BTE found 1 apis:
#
# API 1. cord_biological_process(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.1: https://biothings.ncats.io/cord_bp/query?fields=associated_with (POST -d q=GO:0006887&scopes=go)
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 cord_biological_process: 111 hits
#
# After id-to-object translation, BTE retrieved 111 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# In the #1 query, BTE found 111 unique Gene nodes
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'eosinophil degranulation' and 'Gene'. Paths will have 0 intermediate node.
#
#
#
# ========== QUERY #1 -- fetch all Gene entities linked to eosinophil degranulation ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because eosinophil degranulation is of type 'BiologicalProcess', BTE will query our meta-KG for APIs that can take 'BiologicalProcess' as input and 'Gene' as output
#
# BTE found 1 apis:
#
# API 1. cord_biological_process(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.1: https://biothings.ncats.io/cord_bp/query?fields=associated_with (POST -d q=GO:0043308&scopes=go)
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 cord_biological_process: 4 hits
#
# After id-to-object translation, BTE retrieved 4 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# In the #1 query, BTE found 4 unique Gene nodes
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'insulin secretion' and 'Gene'. Paths will have 0 intermediate node.
#
#
#
# ========== QUERY #1 -- fetch all Gene entities linked to insulin secretion ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because insulin secretion is of type 'BiologicalProcess', BTE will query our meta-KG for APIs that can take 'BiologicalProcess' as input and 'Gene' as output
#
# BTE found 1 apis:
#
# API 1. cord_biological_process(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.1: https://biothings.ncats.io/cord_bp/query?fields=associated_with (POST -d q=GO:0030073&scopes=go)
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 cord_biological_process: 91 hits
#
# After id-to-object translation, BTE retrieved 91 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# In the #1 query, BTE found 91 unique Gene nodes
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'mucus secretion' and 'Gene'. Paths will have 0 intermediate node.
#
#
#
# ========== QUERY #1 -- fetch all Gene entities linked to mucus secretion ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because mucus secretion is of type 'BiologicalProcess', BTE will query our meta-KG for APIs that can take 'BiologicalProcess' as input and 'Gene' as output
#
# BTE found 1 apis:
#
# API 1. cord_biological_process(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.1: https://biothings.ncats.io/cord_bp/query?fields=associated_with (POST -d q=GO:0070254&scopes=go)
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 cord_biological_process: 75 hits
#
# After id-to-object translation, BTE retrieved 75 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# In the #1 query, BTE found 75 unique Gene nodes
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'membrane organization' and 'Gene'. Paths will have 0 intermediate node.
#
#
#
# ========== QUERY #1 -- fetch all Gene entities linked to membrane organization ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because membrane organization is of type 'BiologicalProcess', BTE will query our meta-KG for APIs that can take 'BiologicalProcess' as input and 'Gene' as output
#
# BTE found 1 apis:
#
# API 1. cord_biological_process(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.1: https://biothings.ncats.io/cord_bp/query?fields=associated_with (POST -d q=GO:0061024&scopes=go)
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 cord_biological_process: No hits
#
# After id-to-object translation, BTE retrieved 0 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'learning' and 'Gene'. Paths will have 0 intermediate node.
#
#
#
# ========== QUERY #1 -- fetch all Gene entities linked to learning ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because learning is of type 'BiologicalProcess', BTE will query our meta-KG for APIs that can take 'BiologicalProcess' as input and 'Gene' as output
#
# BTE found 1 apis:
#
# API 1. cord_biological_process(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.1: https://biothings.ncats.io/cord_bp/query?fields=associated_with (POST -d q=GO:0007612&scopes=go)
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 cord_biological_process: 351 hits
#
# After id-to-object translation, BTE retrieved 351 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# In the #1 query, BTE found 351 unique Gene nodes
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'neutrophil degranulation' and 'Gene'. Paths will have 0 intermediate node.
#
#
#
# ========== QUERY #1 -- fetch all Gene entities linked to neutrophil degranulation ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because neutrophil degranulation is of type 'BiologicalProcess', BTE will query our meta-KG for APIs that can take 'BiologicalProcess' as input and 'Gene' as output
#
# BTE found 1 apis:
#
# API 1. cord_biological_process(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.1: https://biothings.ncats.io/cord_bp/query?fields=associated_with (POST -d q=GO:0043312&scopes=go)
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 cord_biological_process: 12 hits
#
# After id-to-object translation, BTE retrieved 12 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# In the #1 query, BTE found 12 unique Gene nodes
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'Golgi to plasma membrane protein transport' and 'Gene'. Paths will have 0 intermediate node.
#
#
#
# ========== QUERY #1 -- fetch all Gene entities linked to Golgi to plasma membrane protein transport ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because Golgi to plasma membrane protein transport is of type 'BiologicalProcess', BTE will query our meta-KG for APIs that can take 'BiologicalProcess' as input and 'Gene' as output
#
# BTE found 1 apis:
#
# API 1. cord_biological_process(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.1: https://biothings.ncats.io/cord_bp/query?fields=associated_with (POST -d q=GO:0043001&scopes=go)
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 cord_biological_process: No hits
#
# After id-to-object translation, BTE retrieved 0 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'regulation of histamine secretion by mast cell' and 'Gene'. Paths will have 0 intermediate node.
#
#
#
# ========== QUERY #1 -- fetch all Gene entities linked to regulation of histamine secretion by mast cell ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because regulation of histamine secretion by mast cell is of type 'BiologicalProcess', BTE will query our meta-KG for APIs that can take 'BiologicalProcess' as input and 'Gene' as output
#
# BTE found 1 apis:
#
# API 1. cord_biological_process(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.1: https://biothings.ncats.io/cord_bp/query?fields=associated_with (POST -d q=GO:1903593&scopes=go)
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 cord_biological_process: No hits
#
# After id-to-object translation, BTE retrieved 0 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'regulation of delayed rectifier potassium channel activity' and 'Gene'. Paths will have 0 intermediate node.
#
#
#
# ========== QUERY #1 -- fetch all Gene entities linked to regulation of delayed rectifier potassium channel activity ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because regulation of delayed rectifier potassium channel activity is of type 'BiologicalProcess', BTE will query our meta-KG for APIs that can take 'BiologicalProcess' as input and 'Gene' as output
#
# BTE found 1 apis:
#
# API 1. cord_biological_process(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.1: https://biothings.ncats.io/cord_bp/query?fields=associated_with (POST -d q=GO:1902259&scopes=go)
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 cord_biological_process: No hits
#
# After id-to-object translation, BTE retrieved 0 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'regulation of exocytosis' and 'Gene'. Paths will have 0 intermediate node.
#
#
#
# ========== QUERY #1 -- fetch all Gene entities linked to regulation of exocytosis ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because regulation of exocytosis is of type 'BiologicalProcess', BTE will query our meta-KG for APIs that can take 'BiologicalProcess' as input and 'Gene' as output
#
# BTE found 1 apis:
#
# API 1. cord_biological_process(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.1: https://biothings.ncats.io/cord_bp/query?fields=associated_with (POST -d q=GO:0017157&scopes=go)
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 cord_biological_process: No hits
#
# After id-to-object translation, BTE retrieved 0 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'protein-containing complex assembly' and 'Gene'. Paths will have 0 intermediate node.
#
#
#
# ========== QUERY #1 -- fetch all Gene entities linked to protein-containing complex assembly ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because protein-containing complex assembly is of type 'BiologicalProcess', BTE will query our meta-KG for APIs that can take 'BiologicalProcess' as input and 'Gene' as output
#
# BTE found 1 apis:
#
# API 1. cord_biological_process(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.1: https://biothings.ncats.io/cord_bp/query?fields=associated_with (POST -d q=GO:0065003&scopes=go)
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 cord_biological_process: No hits
#
# After id-to-object translation, BTE retrieved 0 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'regulation of vesicle-mediated transport' and 'Gene'. Paths will have 0 intermediate node.
#
#
#
# ========== QUERY #1 -- fetch all Gene entities linked to regulation of vesicle-mediated transport ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because regulation of vesicle-mediated transport is of type 'BiologicalProcess', BTE will query our meta-KG for APIs that can take 'BiologicalProcess' as input and 'Gene' as output
#
# BTE found 1 apis:
#
# API 1. cord_biological_process(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.1: https://biothings.ncats.io/cord_bp/query?fields=associated_with (POST -d q=GO:0060627&scopes=go)
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 cord_biological_process: No hits
#
# After id-to-object translation, BTE retrieved 0 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'membrane fusion' and 'Gene'. Paths will have 0 intermediate node.
#
#
#
# ========== QUERY #1 -- fetch all Gene entities linked to membrane fusion ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because membrane fusion is of type 'BiologicalProcess', BTE will query our meta-KG for APIs that can take 'BiologicalProcess' as input and 'Gene' as output
#
# BTE found 1 apis:
#
# API 1. cord_biological_process(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.1: https://biothings.ncats.io/cord_bp/query?fields=associated_with (POST -d q=GO:0061025&scopes=go)
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 cord_biological_process: 37 hits
#
# After id-to-object translation, BTE retrieved 37 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# In the #1 query, BTE found 37 unique Gene nodes
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'SNARE complex assembly' and 'Gene'. Paths will have 0 intermediate node.
#
#
#
# ========== QUERY #1 -- fetch all Gene entities linked to SNARE complex assembly ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because SNARE complex assembly is of type 'BiologicalProcess', BTE will query our meta-KG for APIs that can take 'BiologicalProcess' as input and 'Gene' as output
#
# BTE found 1 apis:
#
# API 1. cord_biological_process(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.1: https://biothings.ncats.io/cord_bp/query?fields=associated_with (POST -d q=GO:0035493&scopes=go)
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 cord_biological_process: No hits
#
# After id-to-object translation, BTE retrieved 0 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'long-term synaptic potentiation' and 'Gene'. Paths will have 0 intermediate node.
#
#
#
# ========== QUERY #1 -- fetch all Gene entities linked to long-term synaptic potentiation ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because long-term synaptic potentiation is of type 'BiologicalProcess', BTE will query our meta-KG for APIs that can take 'BiologicalProcess' as input and 'Gene' as output
#
# BTE found 1 apis:
#
# API 1. cord_biological_process(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.1: https://biothings.ncats.io/cord_bp/query?fields=associated_with (POST -d q=GO:0060291&scopes=go)
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 cord_biological_process: No hits
#
# After id-to-object translation, BTE retrieved 0 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'calcium-ion regulated exocytosis' and 'Gene'. Paths will have 0 intermediate node.
#
#
#
# ========== QUERY #1 -- fetch all Gene entities linked to calcium-ion regulated exocytosis ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because calcium-ion regulated exocytosis is of type 'BiologicalProcess', BTE will query our meta-KG for APIs that can take 'BiologicalProcess' as input and 'Gene' as output
#
# BTE found 1 apis:
#
# API 1. cord_biological_process(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.1: https://biothings.ncats.io/cord_bp/query?fields=associated_with (POST -d q=GO:0017156&scopes=go)
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 cord_biological_process: No hits
#
# After id-to-object translation, BTE retrieved 0 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'protein transport' and 'Gene'. Paths will have 0 intermediate node.
#
#
#
# ========== QUERY #1 -- fetch all Gene entities linked to protein transport ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because protein transport is of type 'BiologicalProcess', BTE will query our meta-KG for APIs that can take 'BiologicalProcess' as input and 'Gene' as output
#
# BTE found 1 apis:
#
# API 1. cord_biological_process(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.1: https://biothings.ncats.io/cord_bp/query?fields=associated_with (POST -d q=GO:0015031&scopes=go)
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 cord_biological_process: 18 hits
#
# After id-to-object translation, BTE retrieved 18 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# In the #1 query, BTE found 18 unique Gene nodes
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'glutamate secretion' and 'Gene'. Paths will have 0 intermediate node.
#
#
#
# ========== QUERY #1 -- fetch all Gene entities linked to glutamate secretion ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because glutamate secretion is of type 'BiologicalProcess', BTE will query our meta-KG for APIs that can take 'BiologicalProcess' as input and 'Gene' as output
#
# BTE found 1 apis:
#
# API 1. cord_biological_process(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.1: https://biothings.ncats.io/cord_bp/query?fields=associated_with (POST -d q=GO:0014047&scopes=go)
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 cord_biological_process: 1 hits
#
# After id-to-object translation, BTE retrieved 1 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# In the #1 query, BTE found 1 unique Gene nodes
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'UV-damage excision repair' and 'Gene'. Paths will have 0 intermediate node.
#
#
#
# ========== QUERY #1 -- fetch all Gene entities linked to UV-damage excision repair ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because UV-damage excision repair is of type 'BiologicalProcess', BTE will query our meta-KG for APIs that can take 'BiologicalProcess' as input and 'Gene' as output
#
# BTE found 1 apis:
#
# API 1. cord_biological_process(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.1: https://biothings.ncats.io/cord_bp/query?fields=associated_with (POST -d q=GO:0070914&scopes=go)
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 cord_biological_process: 445 hits
#
# After id-to-object translation, BTE retrieved 445 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# In the #1 query, BTE found 445 unique Gene nodes
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'positive regulation of intracellular protein transport' and 'Gene'. Paths will have 0 intermediate node.
#
#
#
# ========== QUERY #1 -- fetch all Gene entities linked to positive regulation of intracellular protein transport ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because positive regulation of intracellular protein transport is of type 'BiologicalProcess', BTE will query our meta-KG for APIs that can take 'BiologicalProcess' as input and 'Gene' as output
#
# BTE found 1 apis:
#
# API 1. cord_biological_process(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.1: https://biothings.ncats.io/cord_bp/query?fields=associated_with (POST -d q=GO:0090316&scopes=go)
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 cord_biological_process: No hits
#
# After id-to-object translation, BTE retrieved 0 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'natural killer cell degranulation' and 'Gene'. Paths will have 0 intermediate node.
#
#
#
# ========== QUERY #1 -- fetch all Gene entities linked to natural killer cell degranulation ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because natural killer cell degranulation is of type 'BiologicalProcess', BTE will query our meta-KG for APIs that can take 'BiologicalProcess' as input and 'Gene' as output
#
# BTE found 1 apis:
#
# API 1. cord_biological_process(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.1: https://biothings.ncats.io/cord_bp/query?fields=associated_with (POST -d q=GO:0043320&scopes=go)
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 cord_biological_process: No hits
#
# After id-to-object translation, BTE retrieved 0 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'MAPK3' and 'epilepsy'. Paths will have 1 intermediate node.
#
# Intermediate node #1 will have these type constraints: ChemicalSubstance
#
#
# ==========
# ========== QUERY #1 -- fetch all ChemicalSubstance entities linked to 'MAPK3' ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because MAPK3 is of type 'Gene', BTE will query our meta-KG for APIs that can take 'Gene' as input and 'ChemicalSubstance' as output
#
# BTE found 10 apis:
#
# API 1. opentarget(1 API call)
# API 2. cord_gene(1 API call)
# API 3. scigraph(1 API call)
# API 4. scibite(1 API call)
# API 5. hmdb(1 API call)
# API 6. dgidb(1 API call)
# API 7. pharos(1 API call)
# API 8. chembio(1 API call)
# API 9. semmed_gene(10 API calls)
# API 10. mychem(3 API calls)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
# API 1.1: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000102882&datasource=chembl&size=100&fields=drug
# API 9.3: https://biothings.ncats.io/semmedgene/query?fields=affects (POST -d q=C1366765&scopes=umls)
# API 9.1: https://biothings.ncats.io/semmedgene/query?fields=negatively_regulates (POST -d q=C1366765&scopes=umls)
# API 9.10: https://biothings.ncats.io/semmedgene/query?fields=positively_regulates (POST -d q=C1366765&scopes=umls)
# API 9.9: https://biothings.ncats.io/semmedgene/query?fields=disrupted_by (POST -d q=C1366765&scopes=umls)
# API 9.2: https://biothings.ncats.io/semmedgene/query?fields=physically_interacts_with (POST -d q=C1366765&scopes=umls)
# API 9.5: https://biothings.ncats.io/semmedgene/query?fields=related_to (POST -d q=C1366765&scopes=umls)
# API 2.1: https://biothings.ncats.io/cord_gene/query?fields=associated_with (POST -d q=6877&scopes=hgnc)
# API 9.8: https://biothings.ncats.io/semmedgene/query?fields=disrupts (POST -d q=C1366765&scopes=umls)
# API 9.4: https://biothings.ncats.io/semmedgene/query?fields=affected_by (POST -d q=C1366765&scopes=umls)
# API 9.7: https://biothings.ncats.io/semmedgene/query?fields=negatively_regulated_by (POST -d q=C1366765&scopes=umls)
# API 9.6: https://biothings.ncats.io/semmedgene/query?fields=positively_regulated_by (POST -d q=C1366765&scopes=umls)
# API 5.1: https://automat.renci.org/cord19-scibite/gene/chemical_substance/NCBIGene:5595
# API 8.1: https://automat.renci.org/chembio/gene/chemical_substance/NCBIGene:5595
# API 3.1: https://automat.renci.org/cord19-scigraph/gene/chemical_substance/NCBIGene:5595
# API 4.1: https://automat.renci.org/hmdb/gene/chemical_substance/NCBIGene:5595
# API 7.1: https://automat.renci.org/pharos/gene/chemical_substance/NCBIGene:5595
# API 6.1: http://dgidb.genome.wustl.edu/api/v2/interactions.json?genes=MAPK3
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 opentarget: 12 hits
# API 9.1 semmed_gene: 14 hits
# API 9.2 semmed_gene: 143 hits
# API 9.3 semmed_gene: No hits
# API 9.4 semmed_gene: No hits
# API 9.5 semmed_gene: No hits
# API 6.1 dgidb: No hits
# API 5.1 scibite: No hits
# API 9.6 semmed_gene: 147 hits
# API 10.1 mychem: 7 hits
# API 3.1 scigraph: No hits
# API 2.1 cord_gene: 96 hits
# API 9.7 semmed_gene: 99 hits
# API 7.1 pharos: No hits
# API 9.8 semmed_gene: No hits
# API 8.1 chembio: No hits
# API 10.2 mychem: No hits
# API 9.9 semmed_gene: No hits
# API 4.1 hmdb: No hits
# API 10.3 mychem: 11 hits
# API 9.10 semmed_gene: 34 hits
#
# After id-to-object translation, BTE retrieved 434 unique objects.
#
#
# ==========
# ========== QUERY #2 -- fetch all ChemicalSubstance entities linked to 'epilepsy' ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because epilepsy is of type 'Disease', BTE will query our meta-KG for APIs that can take 'Disease' as input and 'ChemicalSubstance' as output
#
# BTE found 8 apis:
#
# API 1. cord_disease(1 API call)
# API 2. scigraph(1 API call)
# API 3. hmdb(1 API call)
# API 4. scibite(1 API call)
# API 5. semmed_disease(15 API calls)
# API 6. pharos(1 API call)
# API 7. mychem(2 API calls)
# API 8. mydisease(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 5.1: https://biothings.ncats.io/semmed/query?fields=physically_interacts_with (POST -d q=C0014544&scopes=umls)
# API 8.1: https://mydisease.info/v1/query?fields=ctd.chemical_related_to_disease (POST -d q=D004827&scopes=mondo.xrefs.mesh, disgenet.xrefs.mesh)
# API 5.3: https://biothings.ncats.io/semmed/query?fields=coexists_with (POST -d q=C0014544&scopes=umls)
# API 5.2: https://biothings.ncats.io/semmed/query?fields=disrupted_by (POST -d q=C0014544&scopes=umls)
# API 5.7: https://biothings.ncats.io/semmed/query?fields=negatively_regulates (POST -d q=C0014544&scopes=umls)
# API 5.5: https://biothings.ncats.io/semmed/query?fields=derives_from (POST -d q=C0014544&scopes=umls)
# API 5.4: https://biothings.ncats.io/semmed/query?fields=prevented_by (POST -d q=C0014544&scopes=umls)
# API 5.13: https://biothings.ncats.io/semmed/query?fields=derives_info (POST -d q=C0014544&scopes=umls)
# API 1.1: https://biothings.ncats.io/cord_disease/query?fields=associated_with (POST -d q=DOID:1826&scopes=doid)
# API 5.14: https://biothings.ncats.io/semmed/query?fields=negatively_regulated_by (POST -d q=C0014544&scopes=umls)
# API 5.12: https://biothings.ncats.io/semmed/query?fields=affected_by (POST -d q=C0014544&scopes=umls)
# API 5.15: https://biothings.ncats.io/semmed/query?fields=positively_regulated_by (POST -d q=C0014544&scopes=umls)
# API 5.8: https://biothings.ncats.io/semmed/query?fields=treated_by (POST -d q=C0014544&scopes=umls)
# API 5.6: https://biothings.ncats.io/semmed/query?fields=caused_by (POST -d q=C0014544&scopes=umls)
# API 5.9: https://biothings.ncats.io/semmed/query?fields=related_to (POST -d q=C0014544&scopes=umls)
# API 4.1: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0005027
# API 5.10: https://biothings.ncats.io/semmed/query?fields=affects (POST -d q=C0014544&scopes=umls)
# API 3.1: https://automat.renci.org/cord19-scibite/disease/chemical_substance/MONDO:0005027
# API 5.11: https://biothings.ncats.io/semmed/query?fields=positively_regulates (POST -d q=C0014544&scopes=umls)
# API 2.1: https://automat.renci.org/cord19-scigraph/disease/chemical_substance/MONDO:0005027
# API 6.1: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0005027
#
#
# ==== Step #3: Output normalization ====
#
# API 7.1 mychem: 245 hits
# API 4.1 hmdb: No hits
# API 5.1 semmed_disease: No hits
# API 5.2 semmed_disease: 63 hits
# API 7.2 mychem: 26 hits
# API 5.3 semmed_disease: No hits
# API 1.1 cord_disease: 74 hits
# API 2.1 scigraph: No hits
# API 5.4 semmed_disease: 68 hits
# API 5.5 semmed_disease: No hits
# API 3.1 scibite: No hits
# API 5.6 semmed_disease: 232 hits
# API 6.1 pharos: No hits
# API 5.7 semmed_disease: No hits
# API 5.8 semmed_disease: 673 hits
# API 5.9 semmed_disease: 203 hits
# API 5.10 semmed_disease: No hits
# API 5.11 semmed_disease: No hits
# API 5.12 semmed_disease: 227 hits
# API 5.13 semmed_disease: No hits
# API 5.14 semmed_disease: No hits
# API 8.1 mydisease: 155 hits
# API 5.15 semmed_disease: No hits
#
# After id-to-object translation, BTE retrieved 1318 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# BTE found 114 unique intermediate nodes connecting 'MAPK3' and 'epilepsy'
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'MAPK3' and 'autism (disease)'. Paths will have 1 intermediate node.
#
# Intermediate node #1 will have these type constraints: ChemicalSubstance
#
#
# ==========
# ========== QUERY #1 -- fetch all ChemicalSubstance entities linked to 'MAPK3' ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because MAPK3 is of type 'Gene', BTE will query our meta-KG for APIs that can take 'Gene' as input and 'ChemicalSubstance' as output
#
# BTE found 10 apis:
#
# API 1. opentarget(1 API call)
# API 2. cord_gene(1 API call)
# API 3. scigraph(1 API call)
# API 4. scibite(1 API call)
# API 5. hmdb(1 API call)
# API 6. dgidb(1 API call)
# API 7. pharos(1 API call)
# API 8. chembio(1 API call)
# API 9. semmed_gene(10 API calls)
# API 10. mychem(3 API calls)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.1: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000102882&datasource=chembl&size=100&fields=drug
# API 9.6: https://biothings.ncats.io/semmedgene/query?fields=positively_regulated_by (POST -d q=C1366765&scopes=umls)
# API 9.10: https://biothings.ncats.io/semmedgene/query?fields=positively_regulates (POST -d q=C1366765&scopes=umls)
# API 9.3: https://biothings.ncats.io/semmedgene/query?fields=affects (POST -d q=C1366765&scopes=umls)
# API 9.2: https://biothings.ncats.io/semmedgene/query?fields=physically_interacts_with (POST -d q=C1366765&scopes=umls)
# API 9.5: https://biothings.ncats.io/semmedgene/query?fields=related_to (POST -d q=C1366765&scopes=umls)
# API 9.4: https://biothings.ncats.io/semmedgene/query?fields=affected_by (POST -d q=C1366765&scopes=umls)
# API 2.1: https://biothings.ncats.io/cord_gene/query?fields=associated_with (POST -d q=6877&scopes=hgnc)
# API 9.8: https://biothings.ncats.io/semmedgene/query?fields=disrupts (POST -d q=C1366765&scopes=umls)
# API 9.7: https://biothings.ncats.io/semmedgene/query?fields=negatively_regulated_by (POST -d q=C1366765&scopes=umls)
# API 9.9: https://biothings.ncats.io/semmedgene/query?fields=disrupted_by (POST -d q=C1366765&scopes=umls)
# API 9.1: https://biothings.ncats.io/semmedgene/query?fields=negatively_regulates (POST -d q=C1366765&scopes=umls)
# API 5.1: https://automat.renci.org/cord19-scibite/gene/chemical_substance/NCBIGene:5595
# API 3.1: https://automat.renci.org/cord19-scigraph/gene/chemical_substance/NCBIGene:5595
# API 8.1: https://automat.renci.org/chembio/gene/chemical_substance/NCBIGene:5595
# API 4.1: https://automat.renci.org/hmdb/gene/chemical_substance/NCBIGene:5595
# API 7.1: https://automat.renci.org/pharos/gene/chemical_substance/NCBIGene:5595
# API 6.1: http://dgidb.genome.wustl.edu/api/v2/interactions.json?genes=MAPK3
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 opentarget: 12 hits
# API 9.1 semmed_gene: 14 hits
# API 9.2 semmed_gene: 143 hits
# API 9.3 semmed_gene: No hits
# API 9.4 semmed_gene: No hits
# API 9.5 semmed_gene: No hits
# API 6.1 dgidb: No hits
# API 5.1 scibite: No hits
# API 9.6 semmed_gene: 147 hits
# API 10.1 mychem: 7 hits
# API 3.1 scigraph: No hits
# API 2.1 cord_gene: 96 hits
# API 9.7 semmed_gene: 99 hits
# API 7.1 pharos: No hits
# API 9.8 semmed_gene: No hits
# API 8.1 chembio: No hits
# API 10.2 mychem: No hits
# API 9.9 semmed_gene: No hits
# API 4.1 hmdb: No hits
# API 10.3 mychem: 11 hits
# API 9.10 semmed_gene: 34 hits
#
# After id-to-object translation, BTE retrieved 434 unique objects.
#
#
# ==========
# ========== QUERY #2 -- fetch all ChemicalSubstance entities linked to 'autism (disease)' ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because autism (disease) is of type 'Disease', BTE will query our meta-KG for APIs that can take 'Disease' as input and 'ChemicalSubstance' as output
#
# BTE found 6 apis:
#
# API 1. cord_disease(1 API call)
# API 2. scigraph(1 API call)
# API 3. scibite(1 API call)
# API 4. hmdb(1 API call)
# API 5. pharos(1 API call)
# API 6. mydisease(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.1: https://biothings.ncats.io/cord_disease/query?fields=associated_with (POST -d q=DOID:12849&scopes=doid)
# API 6.1: https://mydisease.info/v1/query?fields=ctd.chemical_related_to_disease (POST -d q=D001321&scopes=mondo.xrefs.mesh, disgenet.xrefs.mesh)
# API 4.1: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0005260
# API 2.1: https://automat.renci.org/cord19-scigraph/disease/chemical_substance/MONDO:0005260
# API 3.1: https://automat.renci.org/cord19-scibite/disease/chemical_substance/MONDO:0005260
# API 5.1: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0005260
#
#
# ==== Step #3: Output normalization ====
#
# API 4.1 hmdb: No hits
# API 1.1 cord_disease: 43 hits
# API 2.1 scigraph: No hits
# API 3.1 scibite: No hits
# API 5.1 pharos: No hits
# API 6.1 mydisease: 105 hits
#
# After id-to-object translation, BTE retrieved 139 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# BTE found 24 unique intermediate nodes connecting 'MAPK3' and 'autism (disease)'
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'MAPK3' and 'intellectual disability'. Paths will have 1 intermediate node.
#
# Intermediate node #1 will have these type constraints: ChemicalSubstance
#
#
# ==========
# ========== QUERY #1 -- fetch all ChemicalSubstance entities linked to 'MAPK3' ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because MAPK3 is of type 'Gene', BTE will query our meta-KG for APIs that can take 'Gene' as input and 'ChemicalSubstance' as output
#
# BTE found 10 apis:
#
# API 1. opentarget(1 API call)
# API 2. cord_gene(1 API call)
# API 3. scigraph(1 API call)
# API 4. scibite(1 API call)
# API 5. hmdb(1 API call)
# API 6. dgidb(1 API call)
# API 7. pharos(1 API call)
# API 8. chembio(1 API call)
# API 9. semmed_gene(10 API calls)
# API 10. mychem(3 API calls)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.1: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000102882&datasource=chembl&size=100&fields=drug
# API 9.1: https://biothings.ncats.io/semmedgene/query?fields=negatively_regulates (POST -d q=C1366765&scopes=umls)
# API 9.8: https://biothings.ncats.io/semmedgene/query?fields=disrupts (POST -d q=C1366765&scopes=umls)
# API 9.6: https://biothings.ncats.io/semmedgene/query?fields=positively_regulated_by (POST -d q=C1366765&scopes=umls)
# API 9.10: https://biothings.ncats.io/semmedgene/query?fields=positively_regulates (POST -d q=C1366765&scopes=umls)
# API 9.3: https://biothings.ncats.io/semmedgene/query?fields=affects (POST -d q=C1366765&scopes=umls)
# API 2.1: https://biothings.ncats.io/cord_gene/query?fields=associated_with (POST -d q=6877&scopes=hgnc)
# API 9.9: https://biothings.ncats.io/semmedgene/query?fields=disrupted_by (POST -d q=C1366765&scopes=umls)
# API 9.2: https://biothings.ncats.io/semmedgene/query?fields=physically_interacts_with (POST -d q=C1366765&scopes=umls)
# API 9.7: https://biothings.ncats.io/semmedgene/query?fields=negatively_regulated_by (POST -d q=C1366765&scopes=umls)
# API 9.4: https://biothings.ncats.io/semmedgene/query?fields=affected_by (POST -d q=C1366765&scopes=umls)
# API 9.5: https://biothings.ncats.io/semmedgene/query?fields=related_to (POST -d q=C1366765&scopes=umls)
# API 3.1: https://automat.renci.org/cord19-scigraph/gene/chemical_substance/NCBIGene:5595
# API 5.1: https://automat.renci.org/cord19-scibite/gene/chemical_substance/NCBIGene:5595
# API 4.1: https://automat.renci.org/hmdb/gene/chemical_substance/NCBIGene:5595
# API 8.1: https://automat.renci.org/chembio/gene/chemical_substance/NCBIGene:5595
# API 7.1: https://automat.renci.org/pharos/gene/chemical_substance/NCBIGene:5595
# ...
#
# API 1. cord_disease(1 API call)
# API 2. scigraph(1 API call)
# API 3. hmdb(1 API call)
# API 4. scibite(1 API call)
# API 5. semmed_disease(15 API calls)
# API 6. pharos(1 API call)
# API 7. mychem(2 API calls)
# API 8. mydisease(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 5.5: https://biothings.ncats.io/semmed/query?fields=derives_from (POST -d q=C0014544&scopes=umls)
# API 8.1: https://mydisease.info/v1/query?fields=ctd.chemical_related_to_disease (POST -d q=D004827&scopes=mondo.xrefs.mesh, disgenet.xrefs.mesh)
# API 5.1: https://biothings.ncats.io/semmed/query?fields=physically_interacts_with (POST -d q=C0014544&scopes=umls)
# API 5.14: https://biothings.ncats.io/semmed/query?fields=negatively_regulated_by (POST -d q=C0014544&scopes=umls)
# API 5.11: https://biothings.ncats.io/semmed/query?fields=positively_regulates (POST -d q=C0014544&scopes=umls)
# API 5.6: https://biothings.ncats.io/semmed/query?fields=caused_by (POST -d q=C0014544&scopes=umls)
# API 5.7: https://biothings.ncats.io/semmed/query?fields=negatively_regulates (POST -d q=C0014544&scopes=umls)
# API 5.4: https://biothings.ncats.io/semmed/query?fields=prevented_by (POST -d q=C0014544&scopes=umls)
# API 5.9: https://biothings.ncats.io/semmed/query?fields=related_to (POST -d q=C0014544&scopes=umls)
# API 5.12: https://biothings.ncats.io/semmed/query?fields=affected_by (POST -d q=C0014544&scopes=umls)
# API 5.2: https://biothings.ncats.io/semmed/query?fields=disrupted_by (POST -d q=C0014544&scopes=umls)
# API 5.3: https://biothings.ncats.io/semmed/query?fields=coexists_with (POST -d q=C0014544&scopes=umls)
# API 1.1: https://biothings.ncats.io/cord_disease/query?fields=associated_with (POST -d q=DOID:1826&scopes=doid)
# API 5.8: https://biothings.ncats.io/semmed/query?fields=treated_by (POST -d q=C0014544&scopes=umls)
# API 4.1: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0005027
# API 3.1: https://automat.renci.org/cord19-scibite/disease/chemical_substance/MONDO:0005027
# API 5.15: https://biothings.ncats.io/semmed/query?fields=positively_regulated_by (POST -d q=C0014544&scopes=umls)
# API 2.1: https://automat.renci.org/cord19-scigraph/disease/chemical_substance/MONDO:0005027
# API 5.13: https://biothings.ncats.io/semmed/query?fields=derives_info (POST -d q=C0014544&scopes=umls)
# API 6.1: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0005027
# API 5.10: https://biothings.ncats.io/semmed/query?fields=affects (POST -d q=C0014544&scopes=umls)
#
#
# ==== Step #3: Output normalization ====
#
# API 7.1 mychem: 245 hits
# API 4.1 hmdb: No hits
# API 5.1 semmed_disease: No hits
# API 5.2 semmed_disease: 63 hits
# API 7.2 mychem: 26 hits
# API 5.3 semmed_disease: No hits
# API 1.1 cord_disease: 74 hits
# API 2.1 scigraph: No hits
# API 5.4 semmed_disease: 68 hits
# API 5.5 semmed_disease: No hits
# API 3.1 scibite: No hits
# API 5.6 semmed_disease: 232 hits
# API 6.1 pharos: No hits
# API 5.7 semmed_disease: No hits
# API 5.8 semmed_disease: 673 hits
# API 5.9 semmed_disease: 203 hits
# API 5.10 semmed_disease: No hits
# API 5.11 semmed_disease: No hits
# API 5.12 semmed_disease: 227 hits
# API 5.13 semmed_disease: No hits
# API 5.14 semmed_disease: No hits
# API 8.1 mydisease: 155 hits
# API 5.15 semmed_disease: No hits
#
# After id-to-object translation, BTE retrieved 1318 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# BTE found 533 unique intermediate nodes connecting 'CA2' and 'epilepsy'
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'CA2' and 'autism (disease)'. Paths will have 1 intermediate node.
#
# Intermediate node #1 will have these type constraints: ChemicalSubstance
#
#
# ==========
# ========== QUERY #1 -- fetch all ChemicalSubstance entities linked to 'CA2' ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because CA2 is of type 'Gene', BTE will query our meta-KG for APIs that can take 'Gene' as input and 'ChemicalSubstance' as output
#
# BTE found 10 apis:
#
# API 1. opentarget(1 API call)
# API 2. cord_gene(1 API call)
# API 3. scigraph(1 API call)
# API 4. scibite(1 API call)
# API 5. hmdb(1 API call)
# API 6. dgidb(1 API call)
# API 7. pharos(1 API call)
# API 8. chembio(1 API call)
# API 9. semmed_gene(10 API calls)
# API 10. mychem(3 API calls)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.1: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000104267&datasource=chembl&size=100&fields=drug
# API 9.6: https://biothings.ncats.io/semmedgene/query?fields=positively_regulated_by (POST -d q=C1413043&scopes=umls)
# API 9.2: https://biothings.ncats.io/semmedgene/query?fields=physically_interacts_with (POST -d q=C1413043&scopes=umls)
# API 9.4: https://biothings.ncats.io/semmedgene/query?fields=affected_by (POST -d q=C1413043&scopes=umls)
# API 9.1: https://biothings.ncats.io/semmedgene/query?fields=negatively_regulates (POST -d q=C1413043&scopes=umls)
# API 2.1: https://biothings.ncats.io/cord_gene/query?fields=associated_with (POST -d q=1373&scopes=hgnc)
# API 4.1: https://automat.renci.org/hmdb/gene/chemical_substance/NCBIGene:760
# API 5.1: https://automat.renci.org/cord19-scibite/gene/chemical_substance/NCBIGene:760
# API 9.3: https://biothings.ncats.io/semmedgene/query?fields=affects (POST -d q=C1413043&scopes=umls)
# API 3.1: https://automat.renci.org/cord19-scigraph/gene/chemical_substance/NCBIGene:760
# API 8.1: https://automat.renci.org/chembio/gene/chemical_substance/NCBIGene:760
# API 7.1: https://automat.renci.org/pharos/gene/chemical_substance/NCBIGene:760
# API 9.9: https://biothings.ncats.io/semmedgene/query?fields=disrupted_by (POST -d q=C1413043&scopes=umls)
# API 9.7: https://biothings.ncats.io/semmedgene/query?fields=negatively_regulated_by (POST -d q=C1413043&scopes=umls)
# API 9.5: https://biothings.ncats.io/semmedgene/query?fields=related_to (POST -d q=C1413043&scopes=umls)
# API 9.8: https://biothings.ncats.io/semmedgene/query?fields=disrupts (POST -d q=C1413043&scopes=umls)
# API 9.10: https://biothings.ncats.io/semmedgene/query?fields=positively_regulates (POST -d q=C1413043&scopes=umls)
# API 6.1: http://dgidb.genome.wustl.edu/api/v2/interactions.json?genes=CA2
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 opentarget: 100 hits
# API 9.1 semmed_gene: 359 hits
# API 9.2 semmed_gene: 1569 hits
# API 9.3 semmed_gene: No hits
# API 9.4 semmed_gene: 8 hits
# API 9.5 semmed_gene: No hits
# API 6.1 dgidb: No hits
# API 5.1 scibite: No hits
# API 9.6 semmed_gene: 1294 hits
# API 10.1 mychem: 99 hits
# API 3.1 scigraph: No hits
# API 2.1 cord_gene: 251 hits
# API 9.7 semmed_gene: 1051 hits
# API 7.1 pharos: No hits
# API 9.8 semmed_gene: No hits
# API 8.1 chembio: No hits
# API 10.2 mychem: 2 hits
# API 9.9 semmed_gene: No hits
# API 4.1 hmdb: No hits
# API 10.3 mychem: 64 hits
# API 9.10 semmed_gene: 685 hits
#
# After id-to-object translation, BTE retrieved 3019 unique objects.
#
#
# ==========
# ========== QUERY #2 -- fetch all ChemicalSubstance entities linked to 'autism (disease)' ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because autism (disease) is of type 'Disease', BTE will query our meta-KG for APIs that can take 'Disease' as input and 'ChemicalSubstance' as output
#
# BTE found 6 apis:
#
# API 1. cord_disease(1 API call)
# API 2. scigraph(1 API call)
# API 3. scibite(1 API call)
# API 4. hmdb(1 API call)
# API 5. pharos(1 API call)
# API 6. mydisease(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 6.1: https://mydisease.info/v1/query?fields=ctd.chemical_related_to_disease (POST -d q=D001321&scopes=mondo.xrefs.mesh, disgenet.xrefs.mesh)
# API 1.1: https://biothings.ncats.io/cord_disease/query?fields=associated_with (POST -d q=DOID:12849&scopes=doid)
# API 3.1: https://automat.renci.org/cord19-scibite/disease/chemical_substance/MONDO:0005260
# API 2.1: https://automat.renci.org/cord19-scigraph/disease/chemical_substance/MONDO:0005260
# API 4.1: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0005260
# API 5.1: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0005260
#
#
# ==== Step #3: Output normalization ====
#
# API 4.1 hmdb: No hits
# API 1.1 cord_disease: 43 hits
# API 2.1 scigraph: No hits
# API 3.1 scibite: No hits
# API 5.1 pharos: No hits
# API 6.1 mydisease: 105 hits
#
# After id-to-object translation, BTE retrieved 139 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# BTE found 64 unique intermediate nodes connecting 'CA2' and 'autism (disease)'
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'CA2' and 'intellectual disability'. Paths will have 1 intermediate node.
#
# Intermediate node #1 will have these type constraints: ChemicalSubstance
#
#
# ==========
# ========== QUERY #1 -- fetch all ChemicalSubstance entities linked to 'CA2' ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because CA2 is of type 'Gene', BTE will query our meta-KG for APIs that can take 'Gene' as input and 'ChemicalSubstance' as output
#
# BTE found 10 apis:
#
# API 1. opentarget(1 API call)
# API 2. cord_gene(1 API call)
# API 3. scigraph(1 API call)
# API 4. scibite(1 API call)
# API 5. hmdb(1 API call)
# API 6. dgidb(1 API call)
# API 7. pharos(1 API call)
# API 8. chembio(1 API call)
# API 9. semmed_gene(10 API calls)
# API 10. mychem(3 API calls)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.1: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000104267&datasource=chembl&size=100&fields=drug
# API 9.3: https://biothings.ncats.io/semmedgene/query?fields=affects (POST -d q=C1413043&scopes=umls)
# API 9.2: https://biothings.ncats.io/semmedgene/query?fields=physically_interacts_with (POST -d q=C1413043&scopes=umls)
# API 9.1: https://biothings.ncats.io/semmedgene/query?fields=negatively_regulates (POST -d q=C1413043&scopes=umls)
# API 9.4: https://biothings.ncats.io/semmedgene/query?fields=affected_by (POST -d q=C1413043&scopes=umls)
# API 9.9: https://biothings.ncats.io/semmedgene/query?fields=disrupted_by (POST -d q=C1413043&scopes=umls)
# API 3.1: https://automat.renci.org/cord19-scigraph/gene/chemical_substance/NCBIGene:760
# API 9.8: https://biothings.ncats.io/semmedgene/query?fields=disrupts (POST -d q=C1413043&scopes=umls)
# API 7.1: https://automat.renci.org/pharos/gene/chemical_substance/NCBIGene:760
# API 8.1: https://automat.renci.org/chembio/gene/chemical_substance/NCBIGene:760
# API 5.1: https://automat.renci.org/cord19-scibite/gene/chemical_substance/NCBIGene:760
# API 4.1: https://automat.renci.org/hmdb/gene/chemical_substance/NCBIGene:760
# API 2.1: https://biothings.ncats.io/cord_gene/query?fields=associated_with (POST -d q=1373&scopes=hgnc)
# API 9.6: https://biothings.ncats.io/semmedgene/query?fields=positively_regulated_by (POST -d q=C1413043&scopes=umls)
# API 9.7: https://biothings.ncats.io/semmedgene/query?fields=negatively_regulated_by (POST -d q=C1413043&scopes=umls)
# API 9.10: https://biothings.ncats.io/semmedgene/query?fields=positively_regulates (POST -d q=C1413043&scopes=umls)
# API 9.5: https://biothings.ncats.io/semmedgene/query?fields=related_to (POST -d q=C1413043&scopes=umls)
# API 6.1: http://dgidb.genome.wustl.edu/api/v2/interactions.json?genes=CA2
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 opentarget: 100 hits
# API 9.1 semmed_gene: 359 hits
# API 9.2 semmed_gene: 1569 hits
# API 9.3 semmed_gene: No hits
# API 9.4 semmed_gene: 8 hits
# API 9.5 semmed_gene: No hits
# API 6.1 dgidb: No hits
# API 5.1 scibite: No hits
# API 9.6 semmed_gene: 1294 hits
# API 10.1 mychem: 99 hits
# API 3.1 scigraph: No hits
# API 2.1 cord_gene: 251 hits
# API 9.7 semmed_gene: 1051 hits
# API 7.1 pharos: No hits
# API 9.8 semmed_gene: No hits
# API 8.1 chembio: No hits
# API 10.2 mychem: 2 hits
# API 9.9 semmed_gene: No hits
# API 4.1 hmdb: No hits
# API 10.3 mychem: 64 hits
# API 9.10 semmed_gene: 685 hits
#
# After id-to-object translation, BTE retrieved 3019 unique objects.
#
#
# ==========
# ========== QUERY #2 -- fetch all ChemicalSubstance entities linked to 'intellectual disability' ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because intellectual disability is of type 'Disease', BTE will query our meta-KG for APIs that can take 'Disease' as input and 'ChemicalSubstance' as output
#
# BTE found 8 apis:
#
# API 1. cord_disease(1 API call)
# API 2. scigraph(1 API call)
# API 3. hmdb(1 API call)
# API 4. scibite(1 API call)
# API 5. semmed_disease(15 API calls)
# API 6. pharos(1 API call)
# API 7. mychem(2 API calls)
# API 8. mydisease(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 5.13: https://biothings.ncats.io/semmed/query?fields=derives_info (POST -d q=C3714756&scopes=umls)
# API 5.1: https://biothings.ncats.io/semmed/query?fields=physically_interacts_with (POST -d q=C3714756&scopes=umls)
# API 5.7: https://biothings.ncats.io/semmed/query?fields=negatively_regulates (POST -d q=C3714756&scopes=umls)
# API 1.1: https://biothings.ncats.io/cord_disease/query?fields=associated_with (POST -d q=DOID:1059&scopes=doid)
# API 8.1: https://mydisease.info/v1/query?fields=ctd.chemical_related_to_disease (POST -d q=D008607&scopes=mondo.xrefs.mesh, disgenet.xrefs.mesh)
# API 5.5: https://biothings.ncats.io/semmed/query?fields=derives_from (POST -d q=C3714756&scopes=umls)
# API 5.8: https://biothings.ncats.io/semmed/query?fields=treated_by (POST -d q=C3714756&scopes=umls)
# API 5.11: https://biothings.ncats.io/semmed/query?fields=positively_regulates (POST -d q=C3714756&scopes=umls)
# API 5.6: https://biothings.ncats.io/semmed/query?fields=caused_by (POST -d q=C3714756&scopes=umls)
# API 5.4: https://biothings.ncats.io/semmed/query?fields=prevented_by (POST -d q=C3714756&scopes=umls)
# API 5.9: https://biothings.ncats.io/semmed/query?fields=related_to (POST -d q=C3714756&scopes=umls)
# API 5.2: https://biothings.ncats.io/semmed/query?fields=disrupted_by (POST -d q=C3714756&scopes=umls)
# API 5.12: https://biothings.ncats.io/semmed/query?fields=affected_by (POST -d q=C3714756&scopes=umls)
# API 5.3: https://biothings.ncats.io/semmed/query?fields=coexists_with (POST -d q=C3714756&scopes=umls)
# API 5.10: https://biothings.ncats.io/semmed/query?fields=affects (POST -d q=C3714756&scopes=umls)
# API 5.15: https://biothings.ncats.io/semmed/query?fields=positively_regulated_by (POST -d q=C3714756&scopes=umls)
# API 5.14: https://biothings.ncats.io/semmed/query?fields=negatively_regulated_by (POST -d q=C3714756&scopes=umls)
# API 4.1: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0001071
# API 3.1: https://automat.renci.org/cord19-scibite/disease/chemical_substance/MONDO:0001071
# API 2.1: https://automat.renci.org/cord19-scigraph/disease/chemical_substance/MONDO:0001071
# API 6.1: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0001071
#
#
# ==== Step #3: Output normalization ====
#
# API 7.1 mychem: No hits
# API 4.1 hmdb: No hits
# API 5.1 semmed_disease: No hits
# API 5.2 semmed_disease: No hits
# API 7.2 mychem: No hits
# API 5.3 semmed_disease: No hits
# API 1.1 cord_disease: 10 hits
# API 2.1 scigraph: No hits
# API 5.4 semmed_disease: No hits
# API 5.5 semmed_disease: No hits
# API 3.1 scibite: No hits
# API 5.6 semmed_disease: No hits
# API 6.1 pharos: No hits
# API 5.7 semmed_disease: No hits
# API 5.8 semmed_disease: No hits
# API 5.9 semmed_disease: No hits
# API 5.10 semmed_disease: No hits
# API 5.11 semmed_disease: No hits
# API 5.12 semmed_disease: No hits
# API 5.13 semmed_disease: No hits
# API 5.14 semmed_disease: No hits
# API 8.1 mydisease: 26 hits
# API 5.15 semmed_disease: No hits
#
# After id-to-object translation, BTE retrieved 35 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# BTE found 14 unique intermediate nodes connecting 'CA2' and 'intellectual disability'

# %%
#Results 
test
# Out:
#               BiologicalProcess pred_BP_Gene pred_source  input input_type  \
# 0   SYNAPTIC VESICLE EXOCYTOSIS   related_to        None  MAPK3       Gene
# 1   SYNAPTIC VESICLE EXOCYTOSIS   related_to        None  MAPK3       Gene
# 2   SYNAPTIC VESICLE EXOCYTOSIS   related_to        None  MAPK3       Gene
# 3   SYNAPTIC VESICLE EXOCYTOSIS   related_to        None  MAPK3       Gene
# 4   SYNAPTIC VESICLE EXOCYTOSIS   related_to        None  MAPK3       Gene
# ..                          ...          ...         ...    ...        ...
# 23          GLUTAMATE SECRETION   related_to        None    CA2       Gene
# 24          GLUTAMATE SECRETION   related_to        None    CA2       Gene
# 25          GLUTAMATE SECRETION   related_to        None    CA2       Gene
# 26          GLUTAMATE SECRETION   related_to        None    CA2       Gene
# 27          GLUTAMATE SECRETION   related_to        None    CA2       Gene
#
#                         pred1 pred1_source        pred1_api  \
# 0   physically_interacts_with       SEMMED  SEMMED Gene API
# 1   physically_interacts_with       SEMMED  SEMMED Gene API
# 2   physically_interacts_with       SEMMED  SEMMED Gene API
# 3   physically_interacts_with       SEMMED  SEMMED Gene API
# 4   physically_interacts_with       SEMMED  SEMMED Gene API
# ..                        ...          ...              ...
# 23    negatively_regulated_by       SEMMED  SEMMED Gene API
# 24  physically_interacts_with       SEMMED  SEMMED Gene API
# 25    positively_regulated_by       SEMMED  SEMMED Gene API
# 26    negatively_regulated_by       SEMMED  SEMMED Gene API
# 27    negatively_regulated_by       SEMMED  SEMMED Gene API
#
#                        pred1_pubmed         node1_type  \
# 0                  8626586,22370345  ChemicalSubstance
# 1                  8626586,22370345  ChemicalSubstance
# 2                  8626586,22370345  ChemicalSubstance
# 3                          19046339  ChemicalSubstance
# 4                          19046339  ChemicalSubstance
# ..                              ...                ...
# 23                  2550830,9578025  ChemicalSubstance
# 24  8609904,9291494,9145907,9182535  ChemicalSubstance
# 25       17573636,27655348,11083102  ChemicalSubstance
# 26                          9182535  ChemicalSubstance
# 27                         12164548  ChemicalSubstance
#
#                               node1_name  \
# 0                               C0040549
# 1                               C0040549
# 2                               C0040549
# 3                               C0243076
# 4                               C0243076
# ..                                   ...
# 23  5,5-DIPHENYL-IMIDAZOLIDINE-2,4-DIONE
# 24            BIPHENYLS, POLYCHLORINATED
# 25            BIPHENYLS, POLYCHLORINATED
# 26            BIPHENYLS, POLYCHLORINATED
# 27                         METHYLBENZENE
#
#                                      node1_id        pred2 pred2_source  \
# 0                               UMLS:C0040549   treated_by       SEMMED
# 1                               UMLS:C0040549    caused_by       SEMMED
# 2                               UMLS:C0040549  affected_by       SEMMED
# 3                               UMLS:C0243076   treated_by       SEMMED
# 4                               UMLS:C0243076    caused_by       SEMMED
# ..                                        ...          ...          ...
# 23  name:5,5-DIPHENYL-IMIDAZOLIDINE-2,4-DIONE   related_to          ctd
# 24            name:BIPHENYLS, POLYCHLORINATED   related_to          ctd
# 25            name:BIPHENYLS, POLYCHLORINATED   related_to          ctd
# 26            name:BIPHENYLS, POLYCHLORINATED   related_to          ctd
# 27                         name:METHYLBENZENE   related_to          ctd
#
#              pred2_api                                       pred2_pubmed  \
# 0   SEMMED Disease API                                           21737204
# 1   SEMMED Disease API                                  20840850,22771692
# 2   SEMMED Disease API                                            9610917
# 3   SEMMED Disease API  10511950,18350576,22788917,27434597,3359104,10...
# 4   SEMMED Disease API                          12151117,15250588,9789839
# ..                 ...                                                ...
# 23  mydisease.info API                   10798072,7199765,7294529,9212184
# 24  mydisease.info API                                           27548254
# 25  mydisease.info API                                           27548254
# 26  mydisease.info API                                           27548254
# 27  mydisease.info API                                            9294310
#
#           output_type                output_name            output_id
# 0   ChemicalSubstance                   EPILEPSY  MONDO:MONDO:0005027
# 1   ChemicalSubstance                   EPILEPSY  MONDO:MONDO:0005027
# 2   ChemicalSubstance                   EPILEPSY  MONDO:MONDO:0005027
# 3   ChemicalSubstance                   EPILEPSY  MONDO:MONDO:0005027
# 4   ChemicalSubstance                   EPILEPSY  MONDO:MONDO:0005027
# ..                ...                        ...                  ...
# 23  ChemicalSubstance  INTELLECTUAL DISABILITIES  MONDO:MONDO:0001071
# 24  ChemicalSubstance  INTELLECTUAL DISABILITIES  MONDO:MONDO:0001071
# 25  ChemicalSubstance  INTELLECTUAL DISABILITIES  MONDO:MONDO:0001071
# 26  ChemicalSubstance  INTELLECTUAL DISABILITIES  MONDO:MONDO:0001071
# 27  ChemicalSubstance  INTELLECTUAL DISABILITIES  MONDO:MONDO:0001071
#
# [4293 rows x 19 columns]

# %% [markdown]
# ## Cytoscape
# Documentation https://dash.plotly.com/cytoscape

# %% [markdown]
# ### Data wrangling for Cytoscape

# %%
#Filter columns of interest 
df_entities = test[['BiologicalProcess', "pred_BP_Gene", "pred_source",
                    "input", "pred1", "pred1_pubmed",
                    "node1_name", "pred2", "pred2_pubmed",
                    "output_name"]]


#Rename columns 
df_entities = df_entities.rename(columns = {"pred_source": "source_BP_Gene",
                       "input": "Gene", "pred1": "pred_Gene_CS", "pred1_pubmed": "source_Gene_CS",
                       "node1_name": "ChemicalSubstance", "pred2": "pred_CS_Dis", "pred2_pubmed": "source_CS_Dis",
                       "output_name": "Disease"})

# %%
df_entities
# Out:
#               BiologicalProcess pred_BP_Gene source_BP_Gene   Gene  \
# 0   SYNAPTIC VESICLE EXOCYTOSIS   related_to           None  MAPK3
# 1   SYNAPTIC VESICLE EXOCYTOSIS   related_to           None  MAPK3
# 2   SYNAPTIC VESICLE EXOCYTOSIS   related_to           None  MAPK3
# 3   SYNAPTIC VESICLE EXOCYTOSIS   related_to           None  MAPK3
# 4   SYNAPTIC VESICLE EXOCYTOSIS   related_to           None  MAPK3
# ..                          ...          ...            ...    ...
# 23          GLUTAMATE SECRETION   related_to           None    CA2
# 24          GLUTAMATE SECRETION   related_to           None    CA2
# 25          GLUTAMATE SECRETION   related_to           None    CA2
# 26          GLUTAMATE SECRETION   related_to           None    CA2
# 27          GLUTAMATE SECRETION   related_to           None    CA2
#
#                  pred_Gene_CS                   source_Gene_CS  \
# 0   physically_interacts_with                 8626586,22370345
# 1   physically_interacts_with                 8626586,22370345
# 2   physically_interacts_with                 8626586,22370345
# 3   physically_interacts_with                         19046339
# 4   physically_interacts_with                         19046339
# ..                        ...                              ...
# 23    negatively_regulated_by                  2550830,9578025
# 24  physically_interacts_with  8609904,9291494,9145907,9182535
# 25    positively_regulated_by       17573636,27655348,11083102
# 26    negatively_regulated_by                          9182535
# 27    negatively_regulated_by                         12164548
#
#                        ChemicalSubstance  pred_CS_Dis  \
# 0                               C0040549   treated_by
# 1                               C0040549    caused_by
# 2                               C0040549  affected_by
# 3                               C0243076   treated_by
# 4                               C0243076    caused_by
# ..                                   ...          ...
# 23  5,5-DIPHENYL-IMIDAZOLIDINE-2,4-DIONE   related_to
# 24            BIPHENYLS, POLYCHLORINATED   related_to
# 25            BIPHENYLS, POLYCHLORINATED   related_to
# 26            BIPHENYLS, POLYCHLORINATED   related_to
# 27                         METHYLBENZENE   related_to
#
#                                         source_CS_Dis  \
# 0                                            21737204
# 1                                   20840850,22771692
# 2                                             9610917
# 3   10511950,18350576,22788917,27434597,3359104,10...
# 4                           12151117,15250588,9789839
# ..                                                ...
# 23                   10798072,7199765,7294529,9212184
# 24                                           27548254
# 25                                           27548254
# 26                                           27548254
# 27                                            9294310
#
#                       Disease
# 0                    EPILEPSY
# 1                    EPILEPSY
# 2                    EPILEPSY
# 3                    EPILEPSY
# 4                    EPILEPSY
# ..                        ...
# 23  INTELLECTUAL DISABILITIES
# 24  INTELLECTUAL DISABILITIES
# 25  INTELLECTUAL DISABILITIES
# 26  INTELLECTUAL DISABILITIES
# 27  INTELLECTUAL DISABILITIES
#
# [4293 rows x 10 columns]

# %%
#Create a list from test results
my_list_entities = df_entities.values.tolist()

# %%
my_list_entities
# Out:
# [['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '8626586,22370345',
#   'C0040549',
#   'treated_by',
#   '21737204',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '8626586,22370345',
#   'C0040549',
#   'caused_by',
#   '20840850,22771692',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '8626586,22370345',
#   'C0040549',
#   'affected_by',
#   '9610917',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '19046339',
#   'C0243076',
#   'treated_by',
#   '10511950,18350576,22788917,27434597,3359104,10668446,18221206,27820603,2848606,10514878,24900180,28128443,21686307,3320347,1386786,22035233,17561422,7796325,1686756,12871085',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '19046339',
#   'C0243076',
#   'caused_by',
#   '12151117,15250588,9789839',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '19046339',
#   'C0243076',
#   'affected_by',
#   '24165229',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '22402123,10386601,9602089',
#   'C0243077',
#   'treated_by',
#   '3091036,26044087,1475024,16120487,11907151,25369775,9761322,15550575,18448133,23739002,16540097,4200577,18816300,20143438,28295232,9749739,16409553,29044647,22544534,24090602,27927066,18651664,9134536,26434565,27306063,24287559,28974734,25324731,24550774,28602600,7737333,10553579,25933981,24518170,26633882,11022138,17659477,6472485,17196301,10197052,15136567,19332323,21919845,26557054,15078144,5819132,24086344,11990779,12358316,26163822',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '22402123,10386601,9602089',
#   'C0243077',
#   'caused_by',
#   '25359451,27005990,3927864,14570396,15080894,26162241,16860540',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '22402123,10386601,9602089',
#   'C0243077',
#   'affected_by',
#   '24251559,26122303,22242835,6457305,24001071,8758830,3577804,2537191,12027909,22521826',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '20139904',
#   'C0001128',
#   'caused_by',
#   '26354164,11755897',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '20139904',
#   'C0001128',
#   'affected_by',
#   '2894627,27455554',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '8925922',
#   'C0220806',
#   'caused_by',
#   '2580750',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '16214950',
#   'C0597277',
#   'caused_by',
#   '27668019',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '16214950',
#   'C0597277',
#   'affected_by',
#   '22787644',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '9685331',
#   'C0596235',
#   'related_to',
#   '7528137',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '19268470,26887385',
#   'C1519315',
#   'related_to',
#   '28601603,21467839,10506506',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '15634336',
#   'C1519315',
#   'related_to',
#   '28601603,21467839,10506506',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '25093027',
#   'C0039225',
#   'affected_by',
#   '1822905',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '19608733',
#   'C1328819',
#   'affected_by',
#   '28426698',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'related_to',
#   None,
#   'CHEBI:25741',
#   'related_to',
#   None,
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'related_to',
#   None,
#   'CHEBI:18059',
#   'related_to',
#   None,
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'related_to',
#   None,
#   'CHEBI:23888',
#   'related_to',
#   None,
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'related_to',
#   None,
#   'CHEBI:24433',
#   'related_to',
#   None,
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'related_to',
#   None,
#   'CHEBI:25512',
#   'related_to',
#   None,
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'related_to',
#   None,
#   'CHEBI:22260',
#   'related_to',
#   None,
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'related_to',
#   None,
#   'CHEBI:75958',
#   'related_to',
#   None,
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '26620976',
#   '10,11-DIHYDRO-N,N-DIMETHYL-5H-DIBENZ[B,F]AZEPINE-5-PROPANAMINE',
#   'contraindicated_by',
#   None,
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '26620976',
#   '10,11-DIHYDRO-N,N-DIMETHYL-5H-DIBENZ[B,F]AZEPINE-5-PROPANAMINE',
#   'treated_by',
#   '4626233',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '26620976',
#   '10,11-DIHYDRO-N,N-DIMETHYL-5H-DIBENZ[B,F]AZEPINE-5-PROPANAMINE',
#   'related_to',
#   '5823053',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '21235400',
#   '(-)-MORPHINE',
#   'contraindicated_by',
#   None,
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '9341110',
#   '(-)-MORPHINE',
#   'contraindicated_by',
#   None,
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '21235400',
#   '(-)-MORPHINE',
#   'caused_by',
#   '19183220',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '9341110',
#   '(-)-MORPHINE',
#   'caused_by',
#   '19183220',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '21235400',
#   '(-)-MORPHINE',
#   'affected_by',
#   '7127082,26056076,24464467',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '9341110',
#   '(-)-MORPHINE',
#   'affected_by',
#   '7127082,26056076,24464467',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '21235400',
#   '(-)-MORPHINE',
#   'related_to',
#   '1331416,9583774',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '9341110',
#   '(-)-MORPHINE',
#   'related_to',
#   '1331416,9583774',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '21098865',
#   '10,11-DIHYDRO-N-METHYL-5H-DIBENZO[A,D]CYCLOHEPTENE-DELTA(5,GAMMA)-PROPYLAMINE',
#   'contraindicated_by',
#   None,
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '21098865',
#   '10,11-DIHYDRO-N-METHYL-5H-DIBENZO[A,D]CYCLOHEPTENE-DELTA(5,GAMMA)-PROPYLAMINE',
#   'treated_by',
#   '1233074',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   None,
#   "1,1'-DITHIOBIS(N,N-DIETHYLTHIOFORMAMIDE)",
#   'contraindicated_by',
#   None,
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   None,
#   "1,1'-DITHIOBIS(N,N-DIETHYLTHIOFORMAMIDE)",
#   'affected_by',
#   '976217',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '28740516',
#   '(15S)-PROSTAGLANDIN E2',
#   'contraindicated_by',
#   None,
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'negatively_regulated_by',
#   '22571318',
#   '(15S)-PROSTAGLANDIN E2',
#   'contraindicated_by',
#   None,
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '28740516',
#   '(15S)-PROSTAGLANDIN E2',
#   'prevented_by',
#   '1197778',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'negatively_regulated_by',
#   '22571318',
#   '(15S)-PROSTAGLANDIN E2',
#   'prevented_by',
#   '1197778',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '28558078',
#   '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#   'contraindicated_by',
#   None,
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'negatively_regulated_by',
#   '27765882',
#   '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#   'contraindicated_by',
#   None,
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '28558078',
#   '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#   'treated_by',
#   '7479578,19107990,575378,20096638,2066701',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'negatively_regulated_by',
#   '27765882',
#   '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#   'treated_by',
#   '7479578,19107990,575378,20096638,2066701',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '28558078',
#   '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#   'caused_by',
#   '16243004',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'negatively_regulated_by',
#   '27765882',
#   '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#   'caused_by',
#   '16243004',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '28558078',
#   '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#   'related_to',
#   '2066701',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'negatively_regulated_by',
#   '27765882',
#   '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#   'related_to',
#   '2066701',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '16638579,9572480,9724043',
#   '(+)-PROSTAGLANDIN F2A',
#   'contraindicated_by',
#   None,
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '16638579,9572480,9724043',
#   '(+)-PROSTAGLANDIN F2A',
#   'treated_by',
#   '6579859',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'negatively_regulated_by',
#   '25140399',
#   '(S)-4-PREGNENE-3,20-DIONE',
#   'contraindicated_by',
#   None,
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'related_to',
#   None,
#   '(S)-4-PREGNENE-3,20-DIONE',
#   'contraindicated_by',
#   None,
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'negatively_regulated_by',
#   '25140399',
#   '(S)-4-PREGNENE-3,20-DIONE',
#   'disrupted_by',
#   '24912288,21441632',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'related_to',
#   None,
#   '(S)-4-PREGNENE-3,20-DIONE',
#   'disrupted_by',
#   '24912288,21441632',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'negatively_regulated_by',
#   '25140399',
#   '(S)-4-PREGNENE-3,20-DIONE',
#   'treated_by',
#   '21451944,19125844',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'related_to',
#   None,
#   '(S)-4-PREGNENE-3,20-DIONE',
#   'treated_by',
#   '21451944,19125844',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'negatively_regulated_by',
#   '25140399',
#   '(S)-4-PREGNENE-3,20-DIONE',
#   'caused_by',
#   '16373242',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'related_to',
#   None,
#   '(S)-4-PREGNENE-3,20-DIONE',
#   'caused_by',
#   '16373242',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'negatively_regulated_by',
#   '25140399',
#   '(S)-4-PREGNENE-3,20-DIONE',
#   'related_to',
#   '16981857,17348306,3129539,21787799,24145074',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'related_to',
#   None,
#   '(S)-4-PREGNENE-3,20-DIONE',
#   'related_to',
#   '16981857,17348306,3129539,21787799,24145074',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'negatively_regulated_by',
#   '25140399',
#   '(S)-4-PREGNENE-3,20-DIONE',
#   'affected_by',
#   '2292214',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'related_to',
#   None,
#   '(S)-4-PREGNENE-3,20-DIONE',
#   'affected_by',
#   '2292214',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'negatively_regulated_by',
#   '28623179',
#   '1,2,3,4,10,14B-HEXAHYDRO-2-METHYLPYRAZINO(2,1-A)PYRIDO(2,3-C)BENZAZEPINE',
#   'contraindicated_by',
#   None,
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '24682220',
#   '1,3,7-TRIMETHYL-2,6-DIOXOPURINE',
#   'contraindicated_by',
#   None,
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '24682220',
#   '1,3,7-TRIMETHYL-2,6-DIOXOPURINE',
#   'treated_by',
#   '3554632,12967583,19694796,15121141',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '24682220',
#   '1,3,7-TRIMETHYL-2,6-DIOXOPURINE',
#   'caused_by',
#   '24145078,11903480',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '24682220',
#   '1,3,7-TRIMETHYL-2,6-DIOXOPURINE',
#   'affected_by',
#   '25616462,18409414',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '17196335,12106687,15924567',
#   '(17BETA)-ESTRA-1,3,5(10)-TRIENE-3,17-DIOL',
#   'contraindicated_by',
#   None,
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '17196335,12106687,15924567',
#   '(17BETA)-ESTRA-1,3,5(10)-TRIENE-3,17-DIOL',
#   'treated_by',
#   '3136675,17348306,21924021,22504305,18537772',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '17196335,12106687,15924567',
#   '(17BETA)-ESTRA-1,3,5(10)-TRIENE-3,17-DIOL',
#   'caused_by',
#   '16373242',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '17196335,12106687,15924567',
#   '(17BETA)-ESTRA-1,3,5(10)-TRIENE-3,17-DIOL',
#   'related_to',
#   '23477307,17005180',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '12374781',
#   '(2R,3R,4S,5R)-2-(6-AMINOPURIN-9-YL)-5-(HYDROXYMETHYL)OXOLANE-3,4-DIOL',
#   'disrupted_by',
#   '23783558',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '16324785,14667935',
#   '(2R,3R,4S,5R)-2-(6-AMINOPURIN-9-YL)-5-(HYDROXYMETHYL)OXOLANE-3,4-DIOL',
#   'disrupted_by',
#   '23783558',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulates',
#   '15381038',
#   '(2R,3R,4S,5R)-2-(6-AMINOPURIN-9-YL)-5-(HYDROXYMETHYL)OXOLANE-3,4-DIOL',
#   'disrupted_by',
#   '23783558',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '12374781',
#   '(2R,3R,4S,5R)-2-(6-AMINOPURIN-9-YL)-5-(HYDROXYMETHYL)OXOLANE-3,4-DIOL',
#   'treated_by',
#   '17056128,22496577,25666791,17429216,21320622,21514852,18291597,12823569,12351209',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '16324785,14667935',
#   '(2R,3R,4S,5R)-2-(6-AMINOPURIN-9-YL)-5-(HYDROXYMETHYL)OXOLANE-3,4-DIOL',
#   'treated_by',
#   '17056128,22496577,25666791,17429216,21320622,21514852,18291597,12823569,12351209',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulates',
#   '15381038',
#   '(2R,3R,4S,5R)-2-(6-AMINOPURIN-9-YL)-5-(HYDROXYMETHYL)OXOLANE-3,4-DIOL',
#   'treated_by',
#   '17056128,22496577,25666791,17429216,21320622,21514852,18291597,12823569,12351209',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '12374781',
#   '(2R,3R,4S,5R)-2-(6-AMINOPURIN-9-YL)-5-(HYDROXYMETHYL)OXOLANE-3,4-DIOL',
#   'prevented_by',
#   '19674057',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '16324785,14667935',
#   '(2R,3R,4S,5R)-2-(6-AMINOPURIN-9-YL)-5-(HYDROXYMETHYL)OXOLANE-3,4-DIOL',
#   'prevented_by',
#   '19674057',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulates',
#   '15381038',
#   '(2R,3R,4S,5R)-2-(6-AMINOPURIN-9-YL)-5-(HYDROXYMETHYL)OXOLANE-3,4-DIOL',
#   'prevented_by',
#   '19674057',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '12374781',
#   '(2R,3R,4S,5R)-2-(6-AMINOPURIN-9-YL)-5-(HYDROXYMETHYL)OXOLANE-3,4-DIOL',
#   'related_to',
#   '7660943,26944097,26341819,16846657,27337,18634566,26809224,26550535',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '16324785,14667935',
#   '(2R,3R,4S,5R)-2-(6-AMINOPURIN-9-YL)-5-(HYDROXYMETHYL)OXOLANE-3,4-DIOL',
#   'related_to',
#   '7660943,26944097,26341819,16846657,27337,18634566,26809224,26550535',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulates',
#   '15381038',
#   '(2R,3R,4S,5R)-2-(6-AMINOPURIN-9-YL)-5-(HYDROXYMETHYL)OXOLANE-3,4-DIOL',
#   'related_to',
#   '7660943,26944097,26341819,16846657,27337,18634566,26809224,26550535',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '12374781',
#   '(2R,3R,4S,5R)-2-(6-AMINOPURIN-9-YL)-5-(HYDROXYMETHYL)OXOLANE-3,4-DIOL',
#   'affected_by',
#   '24251559,23134496,20641820,3825555,23662441,20688264,20641184,20641797',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '16324785,14667935',
#   '(2R,3R,4S,5R)-2-(6-AMINOPURIN-9-YL)-5-(HYDROXYMETHYL)OXOLANE-3,4-DIOL',
#   'affected_by',
#   '24251559,23134496,20641820,3825555,23662441,20688264,20641184,20641797',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulates',
#   '15381038',
#   '(2R,3R,4S,5R)-2-(6-AMINOPURIN-9-YL)-5-(HYDROXYMETHYL)OXOLANE-3,4-DIOL',
#   'affected_by',
#   '24251559,23134496,20641820,3825555,23662441,20688264,20641184,20641797',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '12374781',
#   '(2R,3R,4S,5R)-2-(6-AMINOPURIN-9-YL)-5-(HYDROXYMETHYL)OXOLANE-3,4-DIOL',
#   'related_to',
#   '11404469',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '16324785,14667935',
#   '(2R,3R,4S,5R)-2-(6-AMINOPURIN-9-YL)-5-(HYDROXYMETHYL)OXOLANE-3,4-DIOL',
#   'related_to',
#   '11404469',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulates',
#   '15381038',
#   '(2R,3R,4S,5R)-2-(6-AMINOPURIN-9-YL)-5-(HYDROXYMETHYL)OXOLANE-3,4-DIOL',
#   'related_to',
#   '11404469',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '20668027',
#   '3,5-DIAMINO-N-CARBAMIMIDOYL-6-CHLOROPYRAZINE-2-CARBOXAMIDE',
#   'disrupted_by',
#   '26823770',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'related_to',
#   None,
#   '3,5-DIAMINO-N-CARBAMIMIDOYL-6-CHLOROPYRAZINE-2-CARBOXAMIDE',
#   'disrupted_by',
#   '26823770',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '15680253',
#   'CANNABINOIDS',
#   'disrupted_by',
#   '25256087',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '15680253',
#   'CANNABINOIDS',
#   'treated_by',
#   '16044663',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '15680253',
#   'CANNABINOIDS',
#   'caused_by',
#   '29042214',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '15680253',
#   'CANNABINOIDS',
#   'affected_by',
#   '28190698,22079489,25031702,18575801,21177076',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulates',
#   '25118932',
#   '(3BETA,14BETA,17ALPHA)-CHOLEST-5-EN-3-OL',
#   'disrupted_by',
#   '25578735',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulates',
#   '25118932',
#   '(3BETA,14BETA,17ALPHA)-CHOLEST-5-EN-3-OL',
#   'caused_by',
#   '25847620,10215510',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulates',
#   '25118932',
#   '(3BETA,14BETA,17ALPHA)-CHOLEST-5-EN-3-OL',
#   'related_to',
#   '227221,12657888,639773',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulates',
#   '25118932',
#   '(3BETA,14BETA,17ALPHA)-CHOLEST-5-EN-3-OL',
#   'affected_by',
#   '639773',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '23624231',
#   '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#   'disrupted_by',
#   '724821',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'negatively_regulated_by',
#   '28932186',
#   '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#   'disrupted_by',
#   '724821',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'related_to',
#   None,
#   '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#   'disrupted_by',
#   '724821',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '23624231',
#   '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#   'treated_by',
#   '6161049,436860,8519304,1484841,18539563,21277833,2272343,8504778',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'negatively_regulated_by',
#   '28932186',
#   '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#   'treated_by',
#   '6161049,436860,8519304,1484841,18539563,21277833,2272343,8504778',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'related_to',
#   None,
#   '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#   'treated_by',
#   '6161049,436860,8519304,1484841,18539563,21277833,2272343,8504778',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '23624231',
#   '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#   'caused_by',
#   '15175240',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'negatively_regulated_by',
#   '28932186',
#   '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#   'caused_by',
#   '15175240',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'related_to',
#   None,
#   '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#   'caused_by',
#   '15175240',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '23624231',
#   '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#   'related_to',
#   '17156204,27891070,1354399,6878398,12837973,7155280,26550535,8787131',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'negatively_regulated_by',
#   '28932186',
#   '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#   'related_to',
#   '17156204,27891070,1354399,6878398,12837973,7155280,26550535,8787131',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'related_to',
#   None,
#   '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#   'related_to',
#   '17156204,27891070,1354399,6878398,12837973,7155280,26550535,8787131',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '23624231',
#   '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#   'affected_by',
#   '7896243,11860278,497536',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'negatively_regulated_by',
#   '28932186',
#   '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#   'affected_by',
#   '7896243,11860278,497536',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'related_to',
#   None,
#   '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#   'affected_by',
#   '7896243,11860278,497536',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '18786965,19322916,25660312,24970389',
#   'PHARMACEUTICAL PREPARATIONS',
#   'disrupted_by',
#   '24488707,21382442,6235700,17239099,22802329,8330757',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '23184953,22996336,8947491',
#   'PHARMACEUTICAL PREPARATIONS',
#   'disrupted_by',
#   '24488707,21382442,6235700,17239099,22802329,8330757',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'negatively_regulated_by',
#   '19218343',
#   'PHARMACEUTICAL PREPARATIONS',
#   'disrupted_by',
#   '24488707,21382442,6235700,17239099,22802329,8330757',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '18786965,19322916,25660312,24970389',
#   'PHARMACEUTICAL PREPARATIONS',
#   'treated_by',
#   '20402552,15578701,27277800,9578539,28699493,10179626,1780030,2207888,27570661,22147859,4390959,19764603,18790656,21123089,22359775,1425811,8056214,23922658,27371490,9774821,26460786,1998458,12660568,12748177,11129890,9830786,4047105,15073972,16787255,15108592,24148856,2548836,18497720,11903475,15120740,26808161,6466024,27905012,16329630,15000524,27502939,27206757,26689812,24097884,22578218,12151114,15233915,18321235,3091998,21249705,11586114,25891924,24653701,17641270,15514844,27773903,12593467,9137949,1524620,1974307,21131238,13824040,1502014,27703396,23794036,14873679,16299449,27038659,21890242,20285703,27709099,15331974,3888154,12504910,28129569,26654410,12174960,2731087,346272,8009566,9522299,13305556,28199897,22490489,22826747,20268428,8874824,23041031,3891417,16309926,10985999,2998545,26961364,16736,19371546,23124892,27561095,19606480,22327733,20486734,7670770,10880728,28585316,653184,105332,11988901,25114785,25754865,12194504,8902915,19597919,18813732,9408464,9270558,19902809,28810185,1344775,9893695,11139806,27130838,11990774,21084171,27494618,3312929,20519057,27010915,26369628,3174896,17433928,14639055,21488712,2629038,7322163,15250594,25365232,29262473,16412349,27977867,27438184,13165876,18955585,19369673,27601493,10600581,1803310,27780990,24422737,2108511,15501307,2747444,19008076,11918464,16213042,25666791,8159193,23708282,25891927,4082246,23315620,22521336,21933183,3529798,2491904,731433,11606675,17563243,18325027,3519174,24144260,20971172,19998575,21532482,80643,25072779,23598250,26236162,28214777,8800947,15240875,16608372,20077522,12830663,22156364,18852835,25497621,8585122,27678163,21561810,17041593,21501141,12781390,12833886,28757110,28421199,8797068,15578966,2222113,7917080,26444013,11440350,25848093,14574120,13944193,27955713,27857784,24065886,21632214,22937231,6351101,28157274,27823573,15145307,5610944,3116633,1641714,11938788,16545206,7813135,2062415,302660,23756474,2726417,18071153,15021860,11453611,21219341,7892957,10487469,19702736,1562387,16608550,28956955,15901671,8891399,23773767,20882125,27933615,2266549,18446391,14713026,15997944,25688050,12973407,28643873,13211390,16182573,18412635,19233619,11533745,28843182,7504360,24439556,10828313,26362469,3301547,22091599,16432503,24358235,9670671,23216575,7517345,23263794,28478594,22801414,26816494,8057114,11585691,902662,10582773,643,11586113,9144647,22902248,20514770,20490745,23099353,16521062,8891461,7799203,21340067,2222259,16786712,11456438,12094563,15667018,27739362,15240045,12644750,24314750,25675400,11207785,17477369,12002619,12373659,7698529,6175290,8956924,6786823,17199029,8067329,9160401,25893054,21925161,57334,10688275,6616892,22348419,23205960,8995853,23484603,17903210,25556120,19383090,23213564,27922722,17874969,17727739,19298435,17441630,15693726,19040556,8251091,12609248,12445955,18227771,23637949,18691010,1256359,21757378,15744223,18212493,10961630,23720013,24884462,2759846,11461801,7270572,403104,9083902,19166585,15529107,8665530,26248290,15043805,15651315,14687481,7617326,4953288,12383137,10080510,10624382,27492328,4020942,12699868,15380158,20221962,26092099,10760018,17880570,20885118,20927024,25337361,11083162,20815341,20593148,24286873,11222798,24291671,21001984,16563069,17262798,17199014,14394344,28653281,1823294,28212175,8649613,15466993,10030431,19300616,17468205,24648257,17016243,11105304,18627325,28799517,12221238,20689626,26029583,27419661,2857271,1806172,59220,17382806,23424920,28520367,11766777,10768162,12528050,6412156,28225152,25304967,27220560,26415538,22012428,22983234,6439447,22595362,25770414,11767,9340155,22983249,9551295,466126,27599639,17448293,27622799,21292505,3817634,4836028,8378021,22083282,25986191,25068142,8156976,28236577,21951369,3816710,26007701,16375836,856097,27623676,9627204,26141933,25139344,12151112,7301176,8215933,25010262,3140336,26984292,21373707,12470178,9297614,24276653,27498238,11354701,21570745,20505906,466312,13994114,18277339,26324718,24525405,19853217,23650467,25914447,21045168,26182605,11860529 ...
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '23184953,22996336,8947491',
#   'PHARMACEUTICAL PREPARATIONS',
#   'treated_by',
#   '20402552,15578701,27277800,9578539,28699493,10179626,1780030,2207888,27570661,22147859,4390959,19764603,18790656,21123089,22359775,1425811,8056214,23922658,27371490,9774821,26460786,1998458,12660568,12748177,11129890,9830786,4047105,15073972,16787255,15108592,24148856,2548836,18497720,11903475,15120740,26808161,6466024,27905012,16329630,15000524,27502939,27206757,26689812,24097884,22578218,12151114,15233915,18321235,3091998,21249705,11586114,25891924,24653701,17641270,15514844,27773903,12593467,9137949,1524620,1974307,21131238,13824040,1502014,27703396,23794036,14873679,16299449,27038659,21890242,20285703,27709099,15331974,3888154,12504910,28129569,26654410,12174960,2731087,346272,8009566,9522299,13305556,28199897,22490489,22826747,20268428,8874824,23041031,3891417,16309926,10985999,2998545,26961364,16736,19371546,23124892,27561095,19606480,22327733,20486734,7670770,10880728,28585316,653184,105332,11988901,25114785,25754865,12194504,8902915,19597919,18813732,9408464,9270558,19902809,28810185,1344775,9893695,11139806,27130838,11990774,21084171,27494618,3312929,20519057,27010915,26369628,3174896,17433928,14639055,21488712,2629038,7322163,15250594,25365232,29262473,16412349,27977867,27438184,13165876,18955585,19369673,27601493,10600581,1803310,27780990,24422737,2108511,15501307,2747444,19008076,11918464,16213042,25666791,8159193,23708282,25891927,4082246,23315620,22521336,21933183,3529798,2491904,731433,11606675,17563243,18325027,3519174,24144260,20971172,19998575,21532482,80643,25072779,23598250,26236162,28214777,8800947,15240875,16608372,20077522,12830663,22156364,18852835,25497621,8585122,27678163,21561810,17041593,21501141,12781390,12833886,28757110,28421199,8797068,15578966,2222113,7917080,26444013,11440350,25848093,14574120,13944193,27955713,27857784,24065886,21632214,22937231,6351101,28157274,27823573,15145307,5610944,3116633,1641714,11938788,16545206,7813135,2062415,302660,23756474,2726417,18071153,15021860,11453611,21219341,7892957,10487469,19702736,1562387,16608550,28956955,15901671,8891399,23773767,20882125,27933615,2266549,18446391,14713026,15997944,25688050,12973407,28643873,13211390,16182573,18412635,19233619,11533745,28843182,7504360,24439556,10828313,26362469,3301547,22091599,16432503,24358235,9670671,23216575,7517345,23263794,28478594,22801414,26816494,8057114,11585691,902662,10582773,643,11586113,9144647,22902248,20514770,20490745,23099353,16521062,8891461,7799203,21340067,2222259,16786712,11456438,12094563,15667018,27739362,15240045,12644750,24314750,25675400,11207785,17477369,12002619,12373659,7698529,6175290,8956924,6786823,17199029,8067329,9160401,25893054,21925161,57334,10688275,6616892,22348419,23205960,8995853,23484603,17903210,25556120,19383090,23213564,27922722,17874969,17727739,19298435,17441630,15693726,19040556,8251091,12609248,12445955,18227771,23637949,18691010,1256359,21757378,15744223,18212493,10961630,23720013,24884462,2759846,11461801,7270572,403104,9083902,19166585,15529107,8665530,26248290,15043805,15651315,14687481,7617326,4953288,12383137,10080510,10624382,27492328,4020942,12699868,15380158,20221962,26092099,10760018,17880570,20885118,20927024,25337361,11083162,20815341,20593148,24286873,11222798,24291671,21001984,16563069,17262798,17199014,14394344,28653281,1823294,28212175,8649613,15466993,10030431,19300616,17468205,24648257,17016243,11105304,18627325,28799517,12221238,20689626,26029583,27419661,2857271,1806172,59220,17382806,23424920,28520367,11766777,10768162,12528050,6412156,28225152,25304967,27220560,26415538,22012428,22983234,6439447,22595362,25770414,11767,9340155,22983249,9551295,466126,27599639,17448293,27622799,21292505,3817634,4836028,8378021,22083282,25986191,25068142,8156976,28236577,21951369,3816710,26007701,16375836,856097,27623676,9627204,26141933,25139344,12151112,7301176,8215933,25010262,3140336,26984292,21373707,12470178,9297614,24276653,27498238,11354701,21570745,20505906,466312,13994114,18277339,26324718,24525405,19853217,23650467,25914447,21045168,26182605,11860529 ...
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'negatively_regulated_by',
#   '19218343',
#   'PHARMACEUTICAL PREPARATIONS',
#   'treated_by',
#   '20402552,15578701,27277800,9578539,28699493,10179626,1780030,2207888,27570661,22147859,4390959,19764603,18790656,21123089,22359775,1425811,8056214,23922658,27371490,9774821,26460786,1998458,12660568,12748177,11129890,9830786,4047105,15073972,16787255,15108592,24148856,2548836,18497720,11903475,15120740,26808161,6466024,27905012,16329630,15000524,27502939,27206757,26689812,24097884,22578218,12151114,15233915,18321235,3091998,21249705,11586114,25891924,24653701,17641270,15514844,27773903,12593467,9137949,1524620,1974307,21131238,13824040,1502014,27703396,23794036,14873679,16299449,27038659,21890242,20285703,27709099,15331974,3888154,12504910,28129569,26654410,12174960,2731087,346272,8009566,9522299,13305556,28199897,22490489,22826747,20268428,8874824,23041031,3891417,16309926,10985999,2998545,26961364,16736,19371546,23124892,27561095,19606480,22327733,20486734,7670770,10880728,28585316,653184,105332,11988901,25114785,25754865,12194504,8902915,19597919,18813732,9408464,9270558,19902809,28810185,1344775,9893695,11139806,27130838,11990774,21084171,27494618,3312929,20519057,27010915,26369628,3174896,17433928,14639055,21488712,2629038,7322163,15250594,25365232,29262473,16412349,27977867,27438184,13165876,18955585,19369673,27601493,10600581,1803310,27780990,24422737,2108511,15501307,2747444,19008076,11918464,16213042,25666791,8159193,23708282,25891927,4082246,23315620,22521336,21933183,3529798,2491904,731433,11606675,17563243,18325027,3519174,24144260,20971172,19998575,21532482,80643,25072779,23598250,26236162,28214777,8800947,15240875,16608372,20077522,12830663,22156364,18852835,25497621,8585122,27678163,21561810,17041593,21501141,12781390,12833886,28757110,28421199,8797068,15578966,2222113,7917080,26444013,11440350,25848093,14574120,13944193,27955713,27857784,24065886,21632214,22937231,6351101,28157274,27823573,15145307,5610944,3116633,1641714,11938788,16545206,7813135,2062415,302660,23756474,2726417,18071153,15021860,11453611,21219341,7892957,10487469,19702736,1562387,16608550,28956955,15901671,8891399,23773767,20882125,27933615,2266549,18446391,14713026,15997944,25688050,12973407,28643873,13211390,16182573,18412635,19233619,11533745,28843182,7504360,24439556,10828313,26362469,3301547,22091599,16432503,24358235,9670671,23216575,7517345,23263794,28478594,22801414,26816494,8057114,11585691,902662,10582773,643,11586113,9144647,22902248,20514770,20490745,23099353,16521062,8891461,7799203,21340067,2222259,16786712,11456438,12094563,15667018,27739362,15240045,12644750,24314750,25675400,11207785,17477369,12002619,12373659,7698529,6175290,8956924,6786823,17199029,8067329,9160401,25893054,21925161,57334,10688275,6616892,22348419,23205960,8995853,23484603,17903210,25556120,19383090,23213564,27922722,17874969,17727739,19298435,17441630,15693726,19040556,8251091,12609248,12445955,18227771,23637949,18691010,1256359,21757378,15744223,18212493,10961630,23720013,24884462,2759846,11461801,7270572,403104,9083902,19166585,15529107,8665530,26248290,15043805,15651315,14687481,7617326,4953288,12383137,10080510,10624382,27492328,4020942,12699868,15380158,20221962,26092099,10760018,17880570,20885118,20927024,25337361,11083162,20815341,20593148,24286873,11222798,24291671,21001984,16563069,17262798,17199014,14394344,28653281,1823294,28212175,8649613,15466993,10030431,19300616,17468205,24648257,17016243,11105304,18627325,28799517,12221238,20689626,26029583,27419661,2857271,1806172,59220,17382806,23424920,28520367,11766777,10768162,12528050,6412156,28225152,25304967,27220560,26415538,22012428,22983234,6439447,22595362,25770414,11767,9340155,22983249,9551295,466126,27599639,17448293,27622799,21292505,3817634,4836028,8378021,22083282,25986191,25068142,8156976,28236577,21951369,3816710,26007701,16375836,856097,27623676,9627204,26141933,25139344,12151112,7301176,8215933,25010262,3140336,26984292,21373707,12470178,9297614,24276653,27498238,11354701,21570745,20505906,466312,13994114,18277339,26324718,24525405,19853217,23650467,25914447,21045168,26182605,11860529 ...
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '18786965,19322916,25660312,24970389',
#   'PHARMACEUTICAL PREPARATIONS',
#   'prevented_by',
#   '12151114,17033045,23914154,25064738,6848681,1664584,8053271,16439585,24556736,24858213,25324864,28179120,26600369,12109298,26505553,19187289,1483858,18167629,16835945,12151122,15540387,8136193,29028517,12040510,27628962,12151112,17234586,19406251,11465868,11879677',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '23184953,22996336,8947491',
#   'PHARMACEUTICAL PREPARATIONS',
#   'prevented_by',
#   '12151114,17033045,23914154,25064738,6848681,1664584,8053271,16439585,24556736,24858213,25324864,28179120,26600369,12109298,26505553,19187289,1483858,18167629,16835945,12151122,15540387,8136193,29028517,12040510,27628962,12151112,17234586,19406251,11465868,11879677',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'negatively_regulated_by',
#   '19218343',
#   'PHARMACEUTICAL PREPARATIONS',
#   'prevented_by',
#   '12151114,17033045,23914154,25064738,6848681,1664584,8053271,16439585,24556736,24858213,25324864,28179120,26600369,12109298,26505553,19187289,1483858,18167629,16835945,12151122,15540387,8136193,29028517,12040510,27628962,12151112,17234586,19406251,11465868,11879677',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '18786965,19322916,25660312,24970389',
#   'PHARMACEUTICAL PREPARATIONS',
#   'caused_by',
#   '616928,26319171,11143506,15247860,22879864,11907151,10518121,9817790,29075142,11903480,1124270,11212463,10030426,3197684,27865173,13679230,29064811,25540089,6642191,23437388,10855266,25337325,20705092',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '23184953,22996336,8947491',
#   'PHARMACEUTICAL PREPARATIONS',
#   'caused_by',
#   '616928,26319171,11143506,15247860,22879864,11907151,10518121,9817790,29075142,11903480,1124270,11212463,10030426,3197684,27865173,13679230,29064811,25540089,6642191,23437388,10855266,25337325,20705092',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'negatively_regulated_by',
#   '19218343',
#   'PHARMACEUTICAL PREPARATIONS',
#   'caused_by',
#   '616928,26319171,11143506,15247860,22879864,11907151,10518121,9817790,29075142,11903480,1124270,11212463,10030426,3197684,27865173,13679230,29064811,25540089,6642191,23437388,10855266,25337325,20705092',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '18786965,19322916,25660312,24970389',
#   'PHARMACEUTICAL PREPARATIONS',
#   'affected_by',
#   '7467938,7822751,29249510,10829995,10904980,11851635,21353646,9422227,19785797,22827489,23146067,19332328,19254331,9201565,8035901,27770730,21292505,3720698,26970410,24906297,12373665,12474320,27010915,28586743,2734480,21382442,7988517',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '23184953,22996336,8947491',
#   'PHARMACEUTICAL PREPARATIONS',
#   'affected_by',
#   '7467938,7822751,29249510,10829995,10904980,11851635,21353646,9422227,19785797,22827489,23146067,19332328,19254331,9201565,8035901,27770730,21292505,3720698,26970410,24906297,12373665,12474320,27010915,28586743,2734480,21382442,7988517',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'negatively_regulated_by',
#   '19218343',
#   'PHARMACEUTICAL PREPARATIONS',
#   'affected_by',
#   '7467938,7822751,29249510,10829995,10904980,11851635,21353646,9422227,19785797,22827489,23146067,19332328,19254331,9201565,8035901,27770730,21292505,3720698,26970410,24906297,12373665,12474320,27010915,28586743,2734480,21382442,7988517',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '21891976',
#   '3-PYRIDINECARBOXAMIDE',
#   'disrupted_by',
#   '6452183,6215072,6447523',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '21891976',
#   '3-PYRIDINECARBOXAMIDE',
#   'treated_by',
#   '6457475,6235864',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '8660271,17146972,9572480',
#   '(-)-ARTERENOL',
#   'disrupted_by',
#   '2849428',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '8660271,17146972,9572480',
#   '(-)-ARTERENOL',
#   'treated_by',
#   '436860,210417,196232,8504778',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '8660271,17146972,9572480',
#   '(-)-ARTERENOL',
#   'prevented_by',
#   '8845941',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '8660271,17146972,9572480',
#   '(-)-ARTERENOL',
#   'related_to',
#   '7501254,17156204,27891070,7155280,6193838,15465138,12837973',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '29282071',
#   'OILS, VOLATILE',
#   'disrupted_by',
#   '16226415',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '29282071',
#   'OILS, VOLATILE',
#   'treated_by',
#   '26819935,15503777,19577489',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'physically_interacts_with',
#   '29282071',
#   'OILS, VOLATILE',
#   'caused_by',
#   '18852037',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '9227478',
#   '(+/-)-VERAPAMIL',
#   'disrupted_by',
#   '7936095,3113508',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '9227478',
#   '(+/-)-VERAPAMIL',
#   'treated_by',
#   '24113539,28650628,21219313,27513375,8156971,26567612,8281426,17846766,25223728,8891316',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '9227478',
#   '(+/-)-VERAPAMIL',
#   'caused_by',
#   '8281426',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '9227478',
#   '(+/-)-VERAPAMIL',
#   'affected_by',
#   '26567612,8281426',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '11241670',
#   '(-)-RAPAMYCIN',
#   'disrupted_by',
#   '23620711,20566381',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'negatively_regulated_by',
#   '26805420',
#   '(-)-RAPAMYCIN',
#   'disrupted_by',
#   '23620711,20566381',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '11241670',
#   '(-)-RAPAMYCIN',
#   'treated_by',
#   '25752454,26051026,21852879,26995324,26248290,25891924,29098710,28229367,23699517,20419051,23691153,27049136,25599672,22544534,23620711,25591831,24998197,25582464',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'negatively_regulated_by',
#   '26805420',
#   '(-)-RAPAMYCIN',
#   'treated_by',
#   '25752454,26051026,21852879,26995324,26248290,25891924,29098710,28229367,23699517,20419051,23691153,27049136,25599672,22544534,23620711,25591831,24998197,25582464',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '11241670',
#   '(-)-RAPAMYCIN',
#   'prevented_by',
#   '22578218,18389497,26924447,22787661',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'negatively_regulated_by',
#   '26805420',
#   '(-)-RAPAMYCIN',
#   'prevented_by',
#   '22578218,18389497,26924447,22787661',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '11241670',
#   '(-)-RAPAMYCIN',
#   'caused_by',
#   '23699517',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'negatively_regulated_by',
#   '26805420',
#   '(-)-RAPAMYCIN',
#   'caused_by',
#   '23699517',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '11241670',
#   '(-)-RAPAMYCIN',
#   'affected_by',
#   '23743820,21973019',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'negatively_regulated_by',
#   '26805420',
#   '(-)-RAPAMYCIN',
#   'affected_by',
#   '23743820,21973019',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '25832198',
#   'ALPHA TOCOPHEROL',
#   'disrupted_by',
#   '6431729',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '25832198',
#   'ALPHA TOCOPHEROL',
#   'treated_by',
#   '6431729',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '25832198',
#   'ALPHA TOCOPHEROL',
#   'prevented_by',
#   '16604321',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'positively_regulated_by',
#   '25832198',
#   'ALPHA TOCOPHEROL',
#   'related_to',
#   '11846625,8156959',
#   'EPILEPSY'],
#  ['SYNAPTIC VESICLE EXOCYTOSIS',
#   'related_to',
#   None,
#   'MAPK3',
#   'negatively_regulates',
#   '25820186',
#   'MICRORNA',
#   'disrupted_by',
#   '24553459,26168887',
# ...
#   'physically_interacts_with',
#   '7526606',
#   '(11BETA)-11,17,21-TRIHYDROXYPREGN-4-ENE-3,20-DIONE',
#   'contraindicated_by',
#   None,
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'physically_interacts_with',
#   '7526606',
#   '(11BETA)-11,17,21-TRIHYDROXYPREGN-4-ENE-3,20-DIONE',
#   'treated_by',
#   '6487102,21659721,8095891,15816945,21703891,28189919,6096118,4998600,4083853,20205112,3811700,18524542,15781928',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'physically_interacts_with',
#   '7526606',
#   '(11BETA)-11,17,21-TRIHYDROXYPREGN-4-ENE-3,20-DIONE',
#   'related_to',
#   '18524542,3129539,18369387',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'physically_interacts_with',
#   '7526606',
#   '(11BETA)-11,17,21-TRIHYDROXYPREGN-4-ENE-3,20-DIONE',
#   'affected_by',
#   '27036410',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'physically_interacts_with',
#   '3398708',
#   '(-)-MORPHINE',
#   'contraindicated_by',
#   None,
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'physically_interacts_with',
#   '3398708',
#   '(-)-MORPHINE',
#   'caused_by',
#   '19183220',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'physically_interacts_with',
#   '3398708',
#   '(-)-MORPHINE',
#   'affected_by',
#   '7127082,26056076,24464467',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'physically_interacts_with',
#   '3398708',
#   '(-)-MORPHINE',
#   'related_to',
#   '1331416,9583774',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'negatively_regulated_by',
#   '2470519',
#   '(15S)-PROSTAGLANDIN E2',
#   'contraindicated_by',
#   None,
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'negatively_regulated_by',
#   '2470519',
#   '(15S)-PROSTAGLANDIN E2',
#   'prevented_by',
#   '1197778',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'negatively_regulates',
#   '10886095,23578968',
#   '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#   'contraindicated_by',
#   None,
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'physically_interacts_with',
#   '20129744',
#   '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#   'contraindicated_by',
#   None,
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'negatively_regulates',
#   '10886095,23578968',
#   '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#   'treated_by',
#   '7479578,19107990,575378,20096638,2066701',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'physically_interacts_with',
#   '20129744',
#   '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#   'treated_by',
#   '7479578,19107990,575378,20096638,2066701',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'negatively_regulates',
#   '10886095,23578968',
#   '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#   'caused_by',
#   '16243004',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'physically_interacts_with',
#   '20129744',
#   '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#   'caused_by',
#   '16243004',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'negatively_regulates',
#   '10886095,23578968',
#   '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#   'related_to',
#   '2066701',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'physically_interacts_with',
#   '20129744',
#   '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#   'related_to',
#   '2066701',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'negatively_regulated_by',
#   '12623934',
#   'APO-HYDRO',
#   'contraindicated_by',
#   None,
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'negatively_regulated_by',
#   '12623934',
#   'APO-HYDRO',
#   'treated_by',
#   '22661181',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'related_to',
#   None,
#   '(S)-4-PREGNENE-3,20-DIONE',
#   'contraindicated_by',
#   None,
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'related_to',
#   None,
#   '(S)-4-PREGNENE-3,20-DIONE',
#   'disrupted_by',
#   '24912288,21441632',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'related_to',
#   None,
#   '(S)-4-PREGNENE-3,20-DIONE',
#   'treated_by',
#   '21451944,19125844',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'related_to',
#   None,
#   '(S)-4-PREGNENE-3,20-DIONE',
#   'caused_by',
#   '16373242',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'related_to',
#   None,
#   '(S)-4-PREGNENE-3,20-DIONE',
#   'related_to',
#   '16981857,17348306,3129539,21787799,24145074',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'related_to',
#   None,
#   '(S)-4-PREGNENE-3,20-DIONE',
#   'affected_by',
#   '2292214',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'positively_regulates',
#   '15918822',
#   '2,6-BIS(1-METHYLETHYL)PHENOL',
#   'contraindicated_by',
#   None,
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'positively_regulates',
#   '15918822',
#   '2,6-BIS(1-METHYLETHYL)PHENOL',
#   'treated_by',
#   '24518860,7872530,1416122,11244772,8652319,17042840,10364993,2321299,11528301,10849639,8311279,1389823',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'physically_interacts_with',
#   '9129080',
#   'AMINO ACIDS/CARBOHYDRATES/MINERALS/VITAMINS, COMBINATIONS',
#   'disrupted_by',
#   '21613596',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'physically_interacts_with',
#   '9129080',
#   'AMINO ACIDS/CARBOHYDRATES/MINERALS/VITAMINS, COMBINATIONS',
#   'related_to',
#   '13754210',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'physically_interacts_with',
#   '9129080',
#   'AMINO ACIDS/CARBOHYDRATES/MINERALS/VITAMINS, COMBINATIONS',
#   'affected_by',
#   '16510212',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'physically_interacts_with',
#   '29250212',
#   '(3BETA,14BETA,17ALPHA)-CHOLEST-5-EN-3-OL',
#   'disrupted_by',
#   '25578735',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'physically_interacts_with',
#   '29250212',
#   '(3BETA,14BETA,17ALPHA)-CHOLEST-5-EN-3-OL',
#   'caused_by',
#   '25847620,10215510',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'physically_interacts_with',
#   '29250212',
#   '(3BETA,14BETA,17ALPHA)-CHOLEST-5-EN-3-OL',
#   'related_to',
#   '227221,12657888,639773',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'physically_interacts_with',
#   '29250212',
#   '(3BETA,14BETA,17ALPHA)-CHOLEST-5-EN-3-OL',
#   'affected_by',
#   '639773',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'positively_regulated_by',
#   '2287487',
#   'PHARMACEUTICAL PREPARATIONS',
#   'disrupted_by',
#   '24488707,21382442,6235700,17239099,22802329,8330757',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'positively_regulated_by',
#   '2287487',
#   'PHARMACEUTICAL PREPARATIONS',
#   'treated_by',
#   '20402552,15578701,27277800,9578539,28699493,10179626,1780030,2207888,27570661,22147859,4390959,19764603,18790656,21123089,22359775,1425811,8056214,23922658,27371490,9774821,26460786,1998458,12660568,12748177,11129890,9830786,4047105,15073972,16787255,15108592,24148856,2548836,18497720,11903475,15120740,26808161,6466024,27905012,16329630,15000524,27502939,27206757,26689812,24097884,22578218,12151114,15233915,18321235,3091998,21249705,11586114,25891924,24653701,17641270,15514844,27773903,12593467,9137949,1524620,1974307,21131238,13824040,1502014,27703396,23794036,14873679,16299449,27038659,21890242,20285703,27709099,15331974,3888154,12504910,28129569,26654410,12174960,2731087,346272,8009566,9522299,13305556,28199897,22490489,22826747,20268428,8874824,23041031,3891417,16309926,10985999,2998545,26961364,16736,19371546,23124892,27561095,19606480,22327733,20486734,7670770,10880728,28585316,653184,105332,11988901,25114785,25754865,12194504,8902915,19597919,18813732,9408464,9270558,19902809,28810185,1344775,9893695,11139806,27130838,11990774,21084171,27494618,3312929,20519057,27010915,26369628,3174896,17433928,14639055,21488712,2629038,7322163,15250594,25365232,29262473,16412349,27977867,27438184,13165876,18955585,19369673,27601493,10600581,1803310,27780990,24422737,2108511,15501307,2747444,19008076,11918464,16213042,25666791,8159193,23708282,25891927,4082246,23315620,22521336,21933183,3529798,2491904,731433,11606675,17563243,18325027,3519174,24144260,20971172,19998575,21532482,80643,25072779,23598250,26236162,28214777,8800947,15240875,16608372,20077522,12830663,22156364,18852835,25497621,8585122,27678163,21561810,17041593,21501141,12781390,12833886,28757110,28421199,8797068,15578966,2222113,7917080,26444013,11440350,25848093,14574120,13944193,27955713,27857784,24065886,21632214,22937231,6351101,28157274,27823573,15145307,5610944,3116633,1641714,11938788,16545206,7813135,2062415,302660,23756474,2726417,18071153,15021860,11453611,21219341,7892957,10487469,19702736,1562387,16608550,28956955,15901671,8891399,23773767,20882125,27933615,2266549,18446391,14713026,15997944,25688050,12973407,28643873,13211390,16182573,18412635,19233619,11533745,28843182,7504360,24439556,10828313,26362469,3301547,22091599,16432503,24358235,9670671,23216575,7517345,23263794,28478594,22801414,26816494,8057114,11585691,902662,10582773,643,11586113,9144647,22902248,20514770,20490745,23099353,16521062,8891461,7799203,21340067,2222259,16786712,11456438,12094563,15667018,27739362,15240045,12644750,24314750,25675400,11207785,17477369,12002619,12373659,7698529,6175290,8956924,6786823,17199029,8067329,9160401,25893054,21925161,57334,10688275,6616892,22348419,23205960,8995853,23484603,17903210,25556120,19383090,23213564,27922722,17874969,17727739,19298435,17441630,15693726,19040556,8251091,12609248,12445955,18227771,23637949,18691010,1256359,21757378,15744223,18212493,10961630,23720013,24884462,2759846,11461801,7270572,403104,9083902,19166585,15529107,8665530,26248290,15043805,15651315,14687481,7617326,4953288,12383137,10080510,10624382,27492328,4020942,12699868,15380158,20221962,26092099,10760018,17880570,20885118,20927024,25337361,11083162,20815341,20593148,24286873,11222798,24291671,21001984,16563069,17262798,17199014,14394344,28653281,1823294,28212175,8649613,15466993,10030431,19300616,17468205,24648257,17016243,11105304,18627325,28799517,12221238,20689626,26029583,27419661,2857271,1806172,59220,17382806,23424920,28520367,11766777,10768162,12528050,6412156,28225152,25304967,27220560,26415538,22012428,22983234,6439447,22595362,25770414,11767,9340155,22983249,9551295,466126,27599639,17448293,27622799,21292505,3817634,4836028,8378021,22083282,25986191,25068142,8156976,28236577,21951369,3816710,26007701,16375836,856097,27623676,9627204,26141933,25139344,12151112,7301176,8215933,25010262,3140336,26984292,21373707,12470178,9297614,24276653,27498238,11354701,21570745,20505906,466312,13994114,18277339,26324718,24525405,19853217,23650467,25914447,21045168,26182605,11860529 ...
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'positively_regulated_by',
#   '2287487',
#   'PHARMACEUTICAL PREPARATIONS',
#   'prevented_by',
#   '12151114,17033045,23914154,25064738,6848681,1664584,8053271,16439585,24556736,24858213,25324864,28179120,26600369,12109298,26505553,19187289,1483858,18167629,16835945,12151122,15540387,8136193,29028517,12040510,27628962,12151112,17234586,19406251,11465868,11879677',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'positively_regulated_by',
#   '2287487',
#   'PHARMACEUTICAL PREPARATIONS',
#   'caused_by',
#   '616928,26319171,11143506,15247860,22879864,11907151,10518121,9817790,29075142,11903480,1124270,11212463,10030426,3197684,27865173,13679230,29064811,25540089,6642191,23437388,10855266,25337325,20705092',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'positively_regulated_by',
#   '2287487',
#   'PHARMACEUTICAL PREPARATIONS',
#   'affected_by',
#   '7467938,7822751,29249510,10829995,10904980,11851635,21353646,9422227,19785797,22827489,23146067,19332328,19254331,9201565,8035901,27770730,21292505,3720698,26970410,24906297,12373665,12474320,27010915,28586743,2734480,21382442,7988517',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'physically_interacts_with',
#   '27662851',
#   '(-)-RAPAMYCIN',
#   'disrupted_by',
#   '23620711,20566381',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'physically_interacts_with',
#   '27662851',
#   '(-)-RAPAMYCIN',
#   'treated_by',
#   '25752454,26051026,21852879,26995324,26248290,25891924,29098710,28229367,23699517,20419051,23691153,27049136,25599672,22544534,23620711,25591831,24998197,25582464',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'physically_interacts_with',
#   '27662851',
#   '(-)-RAPAMYCIN',
#   'prevented_by',
#   '22578218,18389497,26924447,22787661',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'physically_interacts_with',
#   '27662851',
#   '(-)-RAPAMYCIN',
#   'caused_by',
#   '23699517',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'physically_interacts_with',
#   '27662851',
#   '(-)-RAPAMYCIN',
#   'affected_by',
#   '23743820,21973019',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'physically_interacts_with',
#   '20657750',
#   'MICRORNA',
#   'disrupted_by',
#   '24553459,26168887',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'physically_interacts_with',
#   '20657750',
#   'MICRORNA',
#   'related_to',
#   '23485811,28993242,28676013,26402105,28814872,25410734,26528124,26748106,27840934,28850760,25148080,26663178,23528011,24109432,27839653,25719305,22998082,23049982,26506013,24553459,26910006,25760851,28815576,27207608,28190197,28562528,28331471',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'physically_interacts_with',
#   '27004954',
#   'AGENTS, ANTIHYPERTENSIVE',
#   'treated_by',
#   '9701374,9776332',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'positively_regulated_by',
#   '21849120',
#   '(11BETA,16ALPHA)-9-FLUORO-11,17,21-TRIHYDROXY-16-METHYLPREGNA-1,4-DIENE-3,20-DIONE',
#   'treated_by',
#   '24495842,26980684',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'positively_regulated_by',
#   '21849120',
#   '(11BETA,16ALPHA)-9-FLUORO-11,17,21-TRIHYDROXY-16-METHYLPREGNA-1,4-DIENE-3,20-DIONE',
#   'related_to',
#   '16584647,13866734',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'positively_regulated_by',
#   '21849120',
#   '(11BETA,16ALPHA)-9-FLUORO-11,17,21-TRIHYDROXY-16-METHYLPREGNA-1,4-DIENE-3,20-DIONE',
#   'related_to',
#   None,
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'physically_interacts_with',
#   '27315334',
#   '(+)-GLUCOSE',
#   'treated_by',
#   '1512592,10999517,10636144,7194944,12954424,16787272,12859666,28104740,3748398,24354474,26550535',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'physically_interacts_with',
#   '27315334',
#   '(+)-GLUCOSE',
#   'prevented_by',
#   '17041593',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'physically_interacts_with',
#   '27315334',
#   '(+)-GLUCOSE',
#   'caused_by',
#   '22824994',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'physically_interacts_with',
#   '27315334',
#   '(+)-GLUCOSE',
#   'related_to',
#   '10584972',
#   'EPILEPSY'],
#  ['EOSINOPHIL DEGRANULATION',
#   'related_to',
#   None,
#   'MBP',
#   'physically_interacts_with',
#   '27315334',
#   '(+)-GLUCOSE',
#   'affected_by',
#   '2551458,8118687',
#   'EPILEPSY'],
#  ...]

# %%
#Lists to store elements of interest  
source = [] 
target = []
association_type = []
number_pred_pubmed = []
pred_pubmed = []

for lis in my_list_entities: 
    for index,value in enumerate(lis):
        #Source
        if index % 10 == 0 or index % 10 == 3 or index % 10 == 6: 
                source.append(value)
        #Target
        if index % 10 == 3 or index % 10 == 6 or index % 10 == 9:
                target.append(value)
        #Association 
        elif index % 10 == 1 or index % 10 == 4 or index % 10 == 7:
                association_type.append(value)
        #pubmed Id
        elif index % 10 == 2 or index % 10 == 5 or index % 10 == 8:
                pred_pubmed.append(value)
                
#Number of pubmed IDs 
for result in pred_pubmed:
        if result == None:
            number_pred_pubmed.append(0)
        else:
            number_pred_pubmed.append(result.count(',') + 1) 
        
            
#Create data frame with generated lists 
d = {'source': source, 
    'target': target,
    "association_type": association_type,
    "pred_pubmed": pred_pubmed,
   "number_pred_pubmed": number_pred_pubmed} 
df= pandas.DataFrame(data=d)


df
# Out:
#                             source                      target  \
# 0      SYNAPTIC VESICLE EXOCYTOSIS                       MAPK3
# 1                            MAPK3                    C0040549
# 2                         C0040549                    EPILEPSY
# 3      SYNAPTIC VESICLE EXOCYTOSIS                       MAPK3
# 4                            MAPK3                    C0040549
# ...                            ...                         ...
# 12874                          CA2  BIPHENYLS, POLYCHLORINATED
# 12875   BIPHENYLS, POLYCHLORINATED   INTELLECTUAL DISABILITIES
# 12876          GLUTAMATE SECRETION                         CA2
# 12877                          CA2               METHYLBENZENE
# 12878                METHYLBENZENE   INTELLECTUAL DISABILITIES
#
#                 association_type       pred_pubmed  number_pred_pubmed
# 0                     related_to              None                   0
# 1      physically_interacts_with  8626586,22370345                   2
# 2                     treated_by          21737204                   1
# 3                     related_to              None                   0
# 4      physically_interacts_with  8626586,22370345                   2
# ...                          ...               ...                 ...
# 12874    negatively_regulated_by           9182535                   1
# 12875                 related_to          27548254                   1
# 12876                 related_to              None                   0
# 12877    negatively_regulated_by          12164548                   1
# 12878                 related_to           9294310                   1
#
# [12879 rows x 5 columns]

# %%
#To test results in Cytoscape: Select only the first 500 connections
df = df.head(500)

# %% [markdown]
# ### Cytoscape: Elements = [ ]
# We need to create **elements []** list of dictionaries for Cytoscape. This include the dictionaries for the **"nodes"** and **"edges"**
# #### This is an example of  the structure required fot cytoscape elements list:
# ```
# elements = [
# #Nodes
# { "data": {"id": "BP1", "name": "BP1"},
# "classes": "BiologicalProcess" }}, #This variable will later help us to manipulate each class indepentently
# { "data": {"id": "Gene1", "name": "Gene1"},
# "classes": "Gene" }}
# ....
#
# #Edges
# {'data': {'source': BP1,
# 'target': Gene,
# 'label': related_to,
# "weight": 2}, #Number of pubmed_id
# "group": "edges" }
#
# ]
# ```

# %% [markdown]
# ##### Cytoscape: Nodes.
# We first are going to create the dictionaries of nodes, which includes each of our entities (BP, Gene, CSub, Disease). We are going to iterate through the elements on source and target column in our new data frame

# %%
#Get unique source entities and its index
import numpy as np
value_source, indx_source = np.unique(df["source"].values, return_index = True)

# %%
#Get unique target entities and its index
value_target, indx_target = np.unique(df["target"].values, return_index = True)

# %%
#Cytoscape Node format
my_nodes = []

for i, value in zip(indx_source, value_source):
    if i % 3 == 0: #Index position remainder = 0 (0,3,6,9,12...)
        my_nodes.append({
            "data": {
            "id": value,
            "name": value
            },
            "classes":"BiologicalProcess"})
    elif i % 3 == 1:  #Index position remainder = 1 (1,4,7,10....)
        my_nodes.append({
        "data": {
            "id": value,
            "name": value
            },
        "classes":"Gene"}) 
    elif i % 3 == 2:  #Index position remainder = 2 (2,5,8,11...)
        my_nodes.append({
        "data": {
            "id": value,
            "name": value
            },
        "classes":"ChemicalSubstance"})

for i, value in zip(indx_target,value_target):    
    if i % 3 == 2: #Index position remainder = 2 (2,5,8,11...)
        my_nodes.append({
        "data": {
            "id": value,
            "name": value
            },
        "classes":"Disease"})

# %% [markdown]
# ##### Cytoscape: Edges
# Then we create dictionaries of edges. Each dictionary includes the source and target elements. We are also including the association type between the target and source, and the number of pub_med id that connect this association.

# %%
#Iterate to get Source-Target, the association type and the number of pred_pubmed

my_edges = []
for source,target,asso,pred_num in zip(df["source"], df["target"], 
                              df["association_type"], df["number_pred_pubmed"]):
    my_edges.append({
             'data': {'source': source, #Source
              'target': target, #Target
                'label': [asso], #Association type
                "weight": [pred_num]}, #Number of pred_pubmed ids  
               "group": "edges"    
               })
    
my_edges = [i for j, i in enumerate(my_edges) if i not in my_edges[:j]] #Remove duplicates 
print ((my_edges))
# Out:
# [{'data': {'source': 'SYNAPTIC VESICLE EXOCYTOSIS', 'target': 'MAPK3', 'label': ['related_to'], 'weight': [0]}, 'group': 'edges'}, {'data': {'source': 'MAPK3', 'target': 'C0040549', 'label': ['physically_interacts_with'], 'weight': [2]}, 'group': 'edges'}, {'data': {'source': 'C0040549', 'target': 'EPILEPSY', 'label': ['treated_by'], 'weight': [1]}, 'group': 'edges'}, {'data': {'source': 'C0040549', 'target': 'EPILEPSY', 'label': ['caused_by'], 'weight': [2]}, 'group': 'edges'}, {'data': {'source': 'C0040549', 'target': 'EPILEPSY', 'label': ['affected_by'], 'weight': [1]}, 'group': 'edges'}, {'data': {'source': 'MAPK3', 'target': 'C0243076', 'label': ['physically_interacts_with'], 'weight': [1]}, 'group': 'edges'}, {'data': {'source': 'C0243076', 'target': 'EPILEPSY', 'label': ['treated_by'], 'weight': [20]}, 'group': 'edges'}, {'data': {'source': 'C0243076', 'target': 'EPILEPSY', 'label': ['caused_by'], 'weight': [3]}, 'group': 'edges'}, {'data': {'source': 'C0243076', 'target': 'EPILEPSY', 'label': ['affected_by'], 'weight': [1]}, 'group': 'edges'}, {'data': {'source': 'MAPK3', 'target': 'C0243077', 'label': ['physically_interacts_with'], 'weight': [3]}, 'group': 'edges'}, {'data': {'source': 'C0243077', 'target': 'EPILEPSY', 'label': ['treated_by'], 'weight': [50]}, 'group': 'edges'}, {'data': {'source': 'C0243077', 'target': 'EPILEPSY', 'label': ['caused_by'], 'weight': [7]}, 'group': 'edges'}, {'data': {'source': 'C0243077', 'target': 'EPILEPSY', 'label': ['affected_by'], 'weight': [10]}, 'group': 'edges'}, {'data': {'source': 'MAPK3', 'target': 'C0001128', 'label': ['physically_interacts_with'], 'weight': [1]}, 'group': 'edges'}, {'data': {'source': 'C0001128', 'target': 'EPILEPSY', 'label': ['caused_by'], 'weight': [2]}, 'group': 'edges'}, {'data': {'source': 'C0001128', 'target': 'EPILEPSY', 'label': ['affected_by'], 'weight': [2]}, 'group': 'edges'}, {'data': {'source': 'MAPK3', 'target': 'C0220806', 'label': ['physically_interacts_with'], 'weight': [1]}, 'group': 'edges'}, {'data': {'source': 'C0220806', 'target': 'EPILEPSY', 'label': ['caused_by'], 'weight': [1]}, 'group': 'edges'}, {'data': {'source': 'MAPK3', 'target': 'C0597277', 'label': ['positively_regulated_by'], 'weight': [1]}, 'group': 'edges'}, {'data': {'source': 'C0597277', 'target': 'EPILEPSY', 'label': ['caused_by'], 'weight': [1]}, 'group': 'edges'}, {'data': {'source': 'C0597277', 'target': 'EPILEPSY', 'label': ['affected_by'], 'weight': [1]}, 'group': 'edges'}, {'data': {'source': 'MAPK3', 'target': 'C0596235', 'label': ['positively_regulated_by'], 'weight': [1]}, 'group': 'edges'}, {'data': {'source': 'C0596235', 'target': 'EPILEPSY', 'label': ['related_to'], 'weight': [1]}, 'group': 'edges'}, {'data': {'source': 'MAPK3', 'target': 'C1519315', 'label': ['physically_interacts_with'], 'weight': [2]}, 'group': 'edges'}, {'data': {'source': 'C1519315', 'target': 'EPILEPSY', 'label': ['related_to'], 'weight': [3]}, 'group': 'edges'}, {'data': {'source': 'MAPK3', 'target': 'C1519315', 'label': ['positively_regulated_by'], 'weight': [1]}, 'group': 'edges'}, {'data': {'source': 'MAPK3', 'target': 'C0039225', 'label': ['physically_interacts_with'], 'weight': [1]}, 'group': 'edges'}, {'data': {'source': 'C0039225', 'target': 'EPILEPSY', 'label': ['affected_by'], 'weight': [1]}, 'group': 'edges'}, {'data': {'source': 'MAPK3', 'target': 'C1328819', 'label': ['physically_interacts_with'], 'weight': [1]}, 'group': 'edges'}, {'data': {'source': 'C1328819', 'target': 'EPILEPSY', 'label': ['affected_by'], 'weight': [1]}, 'group': 'edges'}, {'data': {'source': 'MAPK3', 'target': 'CHEBI:25741', 'label': ['related_to'], 'weight': [0]}, 'group': 'edges'}, {'data': {'source': 'CHEBI:25741', 'target': 'EPILEPSY', 'label': ['related_to'], 'weight': [0]}, 'group': 'edges'}, {'data': {'source': 'MAPK3', 'target': 'CHEBI:18059', 'label': ['related_to'], 'weight': [0]}, 'group': 'edges'}, {'data': {'source': 'CHEBI:18059', 'target': 'EPILEPSY', 'label': ['related_to'], 'weigh ...

# %% [markdown]
# ##### Concatenate my_nodes and  my_edges lists
# Finally, we concatenate both list into one.

# %%
my_list_elements = (my_nodes + my_edges)

# %% [markdown]
# ##### Save into file and run it to PyCharm
# We save into a json file and export it ino pycharm

# %%
# #Save list on file using json 
# import json
# with open("vamp2_500_w11.txt", "w") as fp:
#     json.dump(my_list_elements, fp)
